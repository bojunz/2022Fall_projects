# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import random
from datetime import date, timedelta

# %%
df = pd.concat(map(pd.read_csv, ['size_20211.csv', 'size_20212.csv','size_20213.csv',
                                 'size_20214.csv','size_20215.csv','size_20216.csv']))

# %%
df1 = df.loc[df['LNGTH'].notna()] #数据集去掉没有数据的行
df1 = df1[['YEAR','common','LNGTH','WGT','ID_CODE']] #保留的列，[年，鱼的名字，长度，重量，日期代码]
df1['ID_CODE'] = pd.to_datetime(df1['ID_CODE'].astype(str).str[5:-3], format='%Y%m%d') #把日期做成datetime格式
len(df1)
# Out:
# 164565

# %%
start_date = date(2021,1, 1)
end_date = date(2021, 12, 31)
daterange = pd.date_range(start_date, end_date) #设置起始和结束日期

# %%
a = {} #创建一个大字典，key是日期，值是当天钓到鱼的数量
for i in daterange:
    s  = df1.loc[df1['ID_CODE']== i]['common'].value_counts()[0:20]
    s = dict(s)
    b = {str(i)[0:10]:{}}
    b[str(i)[0:10]].update(s)
    a.update(b)
dict_fish_day = a
dict_fish_day
# Out:
# {'2021-01-01': {'SAND SEATROUT': 11,
#   'SHEEPSHEAD': 10,
#   'SOUTHERN KINGFISH': 6,
#   'WHITE GRUNT': 5,
#   'HARDHEAD CATFISH': 4,
#   'GRAY SNAPPER': 4,
#   'WHITE CATFISH': 2,
#   'ATLANTIC CROAKER': 1,
#   'RED DRUM': 1,
#   'BLACK DRUM': 1},
#  '2021-01-02': {'LITTLEHEAD PORGY': 29,
#   'SHEEPSHEAD': 28,
#   'SPOTTED SEATROUT': 23,
#   'WHITE GRUNT': 21,
#   'GRAY SNAPPER': 18,
#   'SAND SEATROUT': 15,
#   'SOUTHERN KINGFISH': 14,
#   'ATLANTIC CROAKER': 10,
#   'BLACK SEA BASS': 9,
#   'WHITE MULLET': 5,
#   'VERMILION SNAPPER': 5,
#   'SAND PERCH': 5,
#   'HOGFISH': 4,
#   'RED PORGY': 3,
#   'LITTLE TUNNY': 2,
#   'PINFISH': 2,
#   'SOUTHERN PUFFER': 2,
#   'LANE SNAPPER': 1,
#   'BLACK MARGATE': 1,
#   'HARDHEAD CATFISH': 1},
#  '2021-01-03': {'ATLANTIC CROAKER': 33,
#   'YELLOWTAIL SNAPPER': 19,
#   'SHEEPSHEAD': 14,
#   'GRAY SNAPPER': 7,
#   'CERO': 6,
#   'ATLANTIC THREAD HERRING': 5,
#   'PINFISH': 5,
#   'VERMILION SNAPPER': 5,
#   'LITTLE TUNNY': 4,
#   'BLACK DRUM': 4,
#   'GULF KINGFISH': 4,
#   'RED DRUM': 3,
#   'SPOTTED SEATROUT': 2,
#   'FLORIDA POMPANO': 2,
#   'PERMIT': 2,
#   'WHITEBONE PORGY': 1,
#   'KNOBBED PORGY': 1,
#   'KING MACKEREL': 1,
#   'BLACKFIN TUNA': 1,
#   'LADYFISH': 1},
#  '2021-01-04': {'SPOTTED SEATROUT': 8,
#   'SHEEPSHEAD': 5,
#   'SPANISH MACKEREL': 2,
#   'BLACKFIN TUNA': 2,
#   'ATLANTIC CROAKER': 2,
#   'CREVALLE JACK': 1,
#   'PINFISH': 1,
#   'BLACK DRUM': 1},
#  '2021-01-05': {'SPOTTED SEATROUT': 17, 'RED DRUM': 1},
#  '2021-01-06': {'ATLANTIC THREAD HERRING': 15,
#   'CERO': 13,
#   'KING MACKEREL': 7,
#   'SPANISH MACKEREL': 6,
#   'YELLOWTAIL SNAPPER': 5,
#   'LITTLE TUNNY': 4,
#   'RED DRUM': 3,
#   'GRAY SNAPPER': 3,
#   'GREAT BARRACUDA': 1,
#   'CREVALLE JACK': 1,
#   'BLACKFIN TUNA': 1,
#   'WAHOO': 1,
#   'GREATER AMBERJACK': 1,
#   'ALMACO JACK': 1},
#  '2021-01-07': {'SHEEPSHEAD': 12,
#   'GRAY SNAPPER': 11,
#   'FLORIDA POMPANO': 4,
#   'HOGFISH': 3,
#   'PINFISH': 2,
#   'LADYFISH': 1,
#   'LITTLEHEAD PORGY': 1},
#  '2021-01-08': {'YELLOWTAIL SNAPPER': 17,
#   'GRAY SNAPPER': 8,
#   'SPANISH MACKEREL': 4,
#   'LITTLE TUNNY': 3,
#   'IRISH POMPANO': 2,
#   'SOUTHERN KINGFISH': 2,
#   'YELLOW JACK': 2,
#   'KING MACKEREL': 2,
#   'MUTTON SNAPPER': 2,
#   'ATLANTIC CROAKER': 1,
#   'BLACKNOSE SHARK': 1,
#   'BLACK DRUM': 1,
#   'RED DRUM': 1},
#  '2021-01-09': {'SPANISH MACKEREL': 18,
#   'SHEEPSHEAD': 7,
#   'LITTLE TUNNY': 6,
#   'VERMILION SNAPPER': 5,
#   'YELLOWTAIL SNAPPER': 5,
#   'CERO': 5,
#   'RED DRUM': 4,
#   'BLUEFISH': 3,
#   'WHITEBONE PORGY': 3,
#   'RED PORGY': 3,
#   'DOLPHIN': 3,
#   'SPOTTED SEATROUT': 2,
#   'SPOTTAIL PINFISH': 1,
#   'MUTTON SNAPPER': 1,
#   'LADYFISH': 1,
#   'BLACK DRUM': 1},
#  '2021-01-10': {'SPANISH MACKEREL': 20,
#   'LANE SNAPPER': 10,
#   'SHEEPSHEAD': 9,
#   'BLUEFISH': 8,
#   'GRAY SNAPPER': 4,
#   'GULF KINGFISH': 3,
#   'RED GROUPER': 3,
#   'SPOTTED SEATROUT': 2,
#   'CERO': 1,
#   'SOUTHERN FLOUNDER': 1},
#  '2021-01-11': {'WHITE GRUNT': 55,
#   'LITTLEHEAD PORGY': 28,
#   'HOGFISH': 12,
#   'GRAY TRIGGERFISH': 4,
#   'LANE SNAPPER': 4,
#   'SOUTHERN PUFFER': 2,
#   'CREVALLE JACK': 2,
#   'YELLOWTAIL SNAPPER': 1,
#   'BLACK SEA BASS': 1,
#   'KNOBBED PORGY': 1,
#   'SAUCEREYE PORGY': 1,
#   'BLUE RUNNER': 1},
#  '2021-01-12': {'LANE SNAPPER': 21,
#   'SHEEPSHEAD': 9,
#   'CREVALLE JACK': 5,
#   'BLACK MARGATE': 5,
#   'GRAY SNAPPER': 3,
#   'SPANISH MACKEREL': 3,
#   'SPOTTAIL PINFISH': 2,
#   'GRAY TRIGGERFISH': 2,
#   'BLUESTRIPED GRUNT': 1,
#   'PIGFISH': 1,
#   'JOLTHEAD PORGY': 1,
#   'BLUE RUNNER': 1},
#  '2021-01-13': {'SHEEPSHEAD': 2},
#  '2021-01-14': {'GRAY SNAPPER': 11,
#   'BLACKFIN TUNA': 9,
#   'SPOTTED SEATROUT': 8,
#   'KING MACKEREL': 8,
#   'SAND SEATROUT': 5,
#   'VERMILION SNAPPER': 4,
#   'MUTTON SNAPPER': 3,
#   'LITTLE TUNNY': 2,
#   'SHEEPSHEAD': 2,
#   'YELLOWTAIL SNAPPER': 2,
#   'SOUTHERN KINGFISH': 2,
#   'BLACK DRUM': 1,
#   'RED DRUM': 1,
#   'GREAT BARRACUDA': 1,
#   'ATLANTIC CROAKER': 1},
#  '2021-01-15': {'SPOTTED SEATROUT': 20,
#   'GULF KINGFISH': 19,
#   'WHITE GRUNT': 12,
#   'SPANISH MACKEREL': 11,
#   'MUTTON SNAPPER': 10,
#   'VERMILION SNAPPER': 9,
#   'SAND PERCH': 8,
#   'LANE SNAPPER': 5,
#   'GRAY SNAPPER': 5,
#   'PERMIT': 5,
#   'BLACKBELLY ROSEFISH': 3,
#   'BLUEFISH': 3,
#   'KING MACKEREL': 3,
#   'GREATER AMBERJACK': 2,
#   'RED PORGY': 2,
#   'KNOBBED PORGY': 2,
#   'CERO': 2,
#   'SPOT': 1,
#   'SOUTHERN KINGFISH': 1,
#   'BERMUDA CHUB': 1},
#  '2021-01-16': {'SHEEPSHEAD': 11,
#   'YELLOWTAIL SNAPPER': 10,
#   'SPOTTED SEATROUT': 1,
#   'BLACK DRUM': 1},
#  '2021-01-17': {'PINFISH': 8,
#   'KING MACKEREL': 7,
#   'GRAY SNAPPER': 7,
#   'SHEEPSHEAD': 7,
#   'DOLPHIN': 6,
#   'SPANISH MACKEREL': 5,
#   'BLUE RUNNER': 3,
#   'SPOTTED SEATROUT': 3,
#   'GREAT BARRACUDA': 1,
#   'CERO': 1,
#   'LITTLE TUNNY': 1,
#   'RED DRUM': 1},
#  '2021-01-18': {'SHEEPSHEAD': 52,
#   'LANE SNAPPER': 20,
#   'GULF KINGFISH': 19,
#   'SPANISH MACKEREL': 18,
#   'YELLOWTAIL SNAPPER': 13,
#   'RED GROUPER': 12,
#   'WHITE GRUNT': 8,
#   'GRAY SNAPPER': 8,
#   'BLUEFISH': 4,
#   'FLORIDA POMPANO': 3,
#   'PINFISH': 2,
#   'KING MACKEREL': 2,
#   'SOUTHERN FLOUNDER': 1,
#   'ATLANTIC CROAKER': 1,
#   'AFRICAN POMPANO': 1,
#   'ATLANTIC SPADEFISH': 1,
#   'SPOTTED SEATROUT': 1,
#   'BLACK CRAPPIE': 1,
#   'SPOT': 1,
#   'BLACK DRUM': 1},
#  '2021-01-19': {'SPOTTED SEATROUT': 15,
#   'SHEEPSHEAD': 11,
#   'SAND SEATROUT': 8,
#   'BLACK DRUM': 5,
#   'GRAY SNAPPER': 3,
#   'MUTTON SNAPPER': 2,
#   'SOUTHERN FLOUNDER': 1,
#   'SPANISH MACKEREL': 1,
#   'BLACKFIN TUNA': 1,
#   'COBIA': 1,
#   'YELLOWTAIL SNAPPER': 1,
#   'LITTLE TUNNY': 1,
#   'DOLPHIN': 1},
#  '2021-01-20': {'SHEEPSHEAD': 7,
#   'PINFISH': 5,
#   'YELLOW JACK': 2,
#   'CERO': 1,
#   'MUTTON SNAPPER': 1,
#   'ATLANTIC CROAKER': 1,
#   'SPOTTED SEATROUT': 1,
#   'RED DRUM': 1},
#  '2021-01-21': {'SPOTTED SEATROUT': 15,
#   'SHEEPSHEAD': 14,
#   'WHITE GRUNT': 5,
#   'GRASS PORGY': 5,
#   'BLACK DRUM': 2,
#   'RED DRUM': 2,
#   'GRAY SNAPPER': 1,
#   'SAUCEREYE PORGY': 1,
#   'LADYFISH': 1},
#  '2021-01-22': {'YELLOWTAIL SNAPPER': 30,
#   'SPANISH MACKEREL': 16,
#   'LANE SNAPPER': 13,
#   'LITTLE TUNNY': 11,
#   'DOLPHIN': 9,
#   'CERO': 9,
#   'PINFISH': 6,
#   'SPOTTED SEATROUT': 6,
#   'KING MACKEREL': 6,
#   'STRIPED MULLET': 5,
#   'MUTTON SNAPPER': 4,
#   'LITTLEHEAD PORGY': 4,
#   'GRAY SNAPPER': 3,
#   'RED DRUM': 2,
#   'VERMILION SNAPPER': 1,
#   'WHITE GRUNT': 1,
#   'JOLTHEAD PORGY': 1,
#   'GREATER AMBERJACK': 1,
#   'AFRICAN POMPANO': 1,
#   'ALMACO JACK': 1},
#  '2021-01-23': {'KING MACKEREL': 86,
#   'BLACKBELLY ROSEFISH': 12,
#   'SHEEPSHEAD': 11,
#   'ALMACO JACK': 7,
#   'LITTLE TUNNY': 7,
#   'SPOTTED SEATROUT': 7,
#   'BLACKFIN TUNA': 6,
#   'RED DRUM': 5,
#   'PINFISH': 4,
#   'YELLOWTAIL SNAPPER': 4,
#   'BLUESTRIPED GRUNT': 3,
#   'GRAY SNAPPER': 2,
#   'YELLOW JACK': 2,
#   'COBIA': 2,
#   'GULF KINGFISH': 2,
#   'BERMUDA CHUB': 2,
#   'BALLYHOO': 2,
#   'BLUE RUNNER': 1,
#   'GREAT BARRACUDA': 1,
#   'GRAY TRIGGERFISH': 1},
#  '2021-01-24': {'YELLOWTAIL SNAPPER': 36,
#   'LANE SNAPPER': 29,
#   'SAND SEATROUT': 25,
#   'GRAY SNAPPER': 18,
#   'CERO': 16,
#   'SPOTTED SEATROUT': 16,
#   'SPANISH MACKEREL': 13,
#   'KING MACKEREL': 10,
#   'JOLTHEAD PORGY': 7,
#   'LITTLEHEAD PORGY': 7,
#   'RED GROUPER': 6,
#   'SAND PERCH': 5,
#   'WHITE PERCH': 5,
#   'SHEEPSHEAD': 4,
#   'AFRICAN POMPANO': 4,
#   'WHITE GRUNT': 4,
#   'LITTLE TUNNY': 4,
#   'RED DRUM': 3,
#   'PINFISH': 2,
#   'VERMILION SNAPPER': 2},
#  '2021-01-25': {'GRAY SNAPPER': 37,
#   'SPOTTED SEATROUT': 23,
#   'YELLOWTAIL SNAPPER': 12,
#   'BALLYHOO': 10,
#   'PINFISH': 10,
#   'CREVALLE JACK': 3,
#   'KING MACKEREL': 3,
#   'WHITE GRUNT': 1,
#   'GREATER AMBERJACK': 1,
#   'CERO': 1,
#   'AFRICAN POMPANO': 1,
#   'LITTLE TUNNY': 1},
#  '2021-01-26': {'WHITE GRUNT': 53,
#   'RED GROUPER': 20,
#   'LITTLEHEAD PORGY': 9,
#   'COBIA': 4,
#   'KING MACKEREL': 4,
#   'SPANISH MACKEREL': 4,
#   'RED DRUM': 4,
#   'LANE SNAPPER': 4,
#   'SOUTHERN PUFFER': 2,
#   'HOGFISH': 2,
#   'SHEEPSHEAD': 1,
#   'BLUE RUNNER': 1,
#   'VERMILION SNAPPER': 1,
#   'KNOBBED PORGY': 1,
#   'SCAMP': 1,
#   'BLACK SEA BASS': 1},
#  '2021-01-27': {'GULF KINGFISH': 11,
#   'SHEEPSHEAD': 11,
#   'GRAY SNAPPER': 11,
#   'SPANISH MACKEREL': 10,
#   'VERMILION SNAPPER': 5,
#   'CREVALLE JACK': 5,
#   'TRIPLETAIL': 4,
#   'SOUTHERN KINGFISH': 4,
#   'WHITEBONE PORGY': 3,
#   'ATLANTIC CROAKER': 3,
#   'LANE SNAPPER': 2},
#  '2021-01-28': {'SPOTTED SEATROUT': 6, 'GRAY SNAPPER': 4},
#  '2021-01-29': {'SOUTHERN KINGFISH': 15,
#   'SAND SEATROUT': 10,
#   'ROUND SCAD': 10,
#   'SHEEPSHEAD': 7,
#   'IRISH POMPANO': 6,
#   'SILVER PERCH': 1,
#   'ATLANTIC CROAKER': 1,
#   'SPOTTAIL PINFISH': 1,
#   'BLACK DRUM': 1,
#   'HARDHEAD CATFISH': 1,
#   'GRAY SNAPPER': 1,
#   'TOMTATE': 1,
#   'VERMILION SNAPPER': 1,
#   'RED DRUM': 1},
#  '2021-01-30': {'WHITE GRUNT': 143,
#   'LITTLEHEAD PORGY': 47,
#   'HOGFISH': 26,
#   'SHEEPSHEAD': 26,
#   'BLACK SEA BASS': 21,
#   'GRAY SNAPPER': 15,
#   'CREVALLE JACK': 10,
#   'KNOBBED PORGY': 8,
#   'SPOTTED SEATROUT': 6,
#   'LANE SNAPPER': 4,
#   'PINFISH': 4,
#   'BLACK DRUM': 4,
#   'LITTLE TUNNY': 4,
#   'WEAKFISH': 3,
#   'VERMILION SNAPPER': 3,
#   'SOUTHERN FLOUNDER': 2,
#   'SAND SEATROUT': 2,
#   'ALMACO JACK': 2,
#   'COBIA': 2,
#   'RED DRUM': 2},
#  '2021-01-31': {'IRISH POMPANO': 10,
#   'GRAY SNAPPER': 8,
#   'CREVALLE JACK': 3,
#   'FLORIDA POMPANO': 1,
#   'MUTTON SNAPPER': 1,
#   'KING MACKEREL': 1,
#   'TRIPLETAIL': 1,
#   'RED DRUM': 1},
#  '2021-02-01': {},
#  '2021-02-02': {},
#  '2021-02-03': {'SHEEPSHEAD': 26,
#   'SPOTTED SEATROUT': 7,
#   'CREVALLE JACK': 2,
#   'LARGEMOUTH BASS': 2},
#  '2021-02-04': {'WHITE GRUNT': 8,
#   'GRAY SNAPPER': 8,
#   'IRISH POMPANO': 6,
#   'SHEEPSHEAD': 2,
#   'ATLANTIC CROAKER': 1,
#   'LITTLEHEAD PORGY': 1},
#  '2021-02-05': {'SPANISH MACKEREL': 42,
#   'SPOTTED SEATROUT': 16,
#   'GULF KINGFISH': 15,
#   'SHEEPSHEAD': 12,
#   'SAND DRUM': 7,
#   'GRAY SNAPPER': 6,
#   'FLORIDA POMPANO': 6,
#   'PINFISH': 5,
#   'CERO': 4,
#   'IRISH POMPANO': 4,
#   'GREAT BARRACUDA': 3,
#   'DOLPHIN': 3,
#   'BLUEFISH': 3,
#   'RED DRUM': 3,
#   'YELLOWTAIL SNAPPER': 3,
#   'JOLTHEAD PORGY': 2,
#   'BLUE RUNNER': 2,
#   'BONNETHEAD': 2,
#   'SPOTTAIL PINFISH': 1,
#   'LITTLEHEAD PORGY': 1},
#  '2021-02-06': {'SPANISH MACKEREL': 23,
#   'BLUE RUNNER': 18,
#   'SHEEPSHEAD': 16,
#   'BLUEFISH': 10,
#   'VERMILION SNAPPER': 8,
#   'ALMACO JACK': 7,
#   'GRAY SNAPPER': 6,
#   'KING MACKEREL': 5,
#   'BLACK MARGATE': 5,
#   'CREVALLE JACK': 5,
#   'LANE SNAPPER': 4,
#   'GREATER AMBERJACK': 3,
#   'GRAYSBY': 3,
#   'RED DRUM': 3,
#   'PINFISH': 3,
#   'LADYFISH': 2,
#   'BLACK DRUM': 2,
#   'TILEFISH': 2,
#   'WAHOO': 2,
#   'DOLPHIN': 1},
#  '2021-02-07': {'GRAY SNAPPER': 22,
#   'WHITE GRUNT': 21,
#   'YELLOWTAIL SNAPPER': 13,
#   'KING MACKEREL': 13,
#   'SPANISH MACKEREL': 9,
#   'LITTLEHEAD PORGY': 8,
#   'LANE SNAPPER': 7,
#   'VERMILION SNAPPER': 6,
#   'BLUESTRIPED GRUNT': 6,
#   'BLUE RUNNER': 6,
#   'SPOTTED SEATROUT': 4,
#   'JOLTHEAD PORGY': 3,
#   'AFRICAN POMPANO': 3,
#   'ALMACO JACK': 2,
#   'FLORIDA POMPANO': 2,
#   'LITTLE TUNNY': 2,
#   'RED DRUM': 1,
#   'CERO': 1,
#   'MUTTON SNAPPER': 1,
#   'STRIPED MULLET': 1},
#  '2021-02-08': {'WHITE GRUNT': 79,
#   'LITTLEHEAD PORGY': 24,
#   'LANE SNAPPER': 21,
#   'PINFISH': 18,
#   'SHEEPSHEAD': 12,
#   'SPANISH MACKEREL': 8,
#   'GRAY SNAPPER': 7,
#   'CERO': 4,
#   'BLACK SEA BASS': 4,
#   'YELLOWTAIL SNAPPER': 4,
#   'ATLANTIC CROAKER': 3,
#   'SAND SEATROUT': 3,
#   'LITTLE TUNNY': 3,
#   'KNOBBED PORGY': 2,
#   'MUTTON SNAPPER': 2,
#   'RED DRUM': 2,
#   'SMOOTH PUFFER': 2,
#   'SOUTHERN PUFFER': 2,
#   'SOUTHERN KINGFISH': 2,
#   'JOLTHEAD PORGY': 1},
#  '2021-02-09': {'BLACK DRUM': 11,
#   'MUTTON SNAPPER': 10,
#   'YELLOWTAIL SNAPPER': 10,
#   'SPANISH MACKEREL': 7,
#   'CREVALLE JACK': 5,
#   'LITTLE TUNNY': 5,
#   'GRAY SNAPPER': 5,
#   'VERMILION SNAPPER': 4,
#   'RED DRUM': 3,
#   'RAINBOW RUNNER': 3,
#   'SOUTHERN KINGFISH': 2,
#   'BLUEFISH': 2,
#   'SHEEPSHEAD': 2,
#   'JOLTHEAD PORGY': 2,
#   'COMMON SNOOK': 2,
#   'CERO': 1,
#   'LANE SNAPPER': 1},
#  '2021-02-10': {'SHEEPSHEAD': 12,
#   'KING MACKEREL': 7,
#   'GRAY SNAPPER': 5,
#   'DOLPHIN': 3,
#   'LANE SNAPPER': 3,
#   'FLORIDA POMPANO': 2,
#   'SPOTTED SEATROUT': 2,
#   'LITTLE TUNNY': 1,
#   'CERO': 1,
#   'GREAT BARRACUDA': 1,
#   'ALMACO JACK': 1,
#   'IRISH POMPANO': 1,
#   'CREVALLE JACK': 1,
#   'MUTTON SNAPPER': 1},
#  '2021-02-11': {'LANE SNAPPER': 47,
#   'KING MACKEREL': 29,
#   'SOUTHERN KINGFISH': 13,
#   'WHITE GRUNT': 7,
#   'GRAY SNAPPER': 6,
#   'LITTLEHEAD PORGY': 6,
#   'SPOTTED SEATROUT': 5,
#   'BLUE RUNNER': 3,
#   'LITTLE TUNNY': 3,
#   'RED GROUPER': 2,
#   'CERO': 2,
#   'FLORIDA POMPANO': 2,
#   'SPANISH MACKEREL': 1,
#   'MUTTON SNAPPER': 1,
#   'GREATER AMBERJACK': 1,
#   'YELLOW JACK': 1,
#   'SHEEPSHEAD': 1,
#   'BLACK SEA BASS': 1,
#   'RED DRUM': 1},
#  '2021-02-12': {'SAND SEATROUT': 8,
#   'SHEEPSHEAD': 5,
#   'SPOTTED SEATROUT': 5,
#   'PINFISH': 5,
#   'CREVALLE JACK': 2,
#   'SAND TILEFISH': 2,
#   'GULF KINGFISH': 1,
#   'WHITE GRUNT': 1,
#   'RED DRUM': 1,
#   'WHITE CATFISH': 1,
#   'FLORIDA POMPANO': 1,
#   'BLACK DRUM': 1,
#   'GRAY TRIGGERFISH': 1,
#   'WHITEBONE PORGY': 1,
#   'LITTLEHEAD PORGY': 1,
#   'RAINBOW RUNNER': 1},
#  '2021-02-13': {'GRAY SNAPPER': 27,
#   'WHITE GRUNT': 13,
#   'LANE SNAPPER': 8,
#   'YELLOWTAIL SNAPPER': 8,
#   'LITTLEHEAD PORGY': 6,
#   'SHEEPSHEAD': 4,
#   'KNOBBED PORGY': 4,
#   'JOLTHEAD PORGY': 2,
#   'GRAY TRIGGERFISH': 1,
#   'VERMILION SNAPPER': 1,
#   'GREATER AMBERJACK': 1,
#   'HOGFISH': 1,
#   'GREAT BARRACUDA': 1},
#  '2021-02-14': {'BLACKFIN TUNA': 14,
#   'KING MACKEREL': 6,
#   'SHEEPSHEAD': 6,
#   'YELLOWTAIL SNAPPER': 6,
#   'VERMILION SNAPPER': 4,
#   'LITTLE TUNNY': 4,
#   'BLACKBELLY ROSEFISH': 3,
#   'DOLPHIN': 3,
#   'GRAY SNAPPER': 2,
#   'LITTLEHEAD PORGY': 2,
#   'SHEEPSHEAD PORGY': 1,
#   'SKIPJACK TUNA': 1,
#   'SAND TILEFISH': 1,
#   'SAUCEREYE PORGY': 1,
#   'GRAY TRIGGERFISH': 1,
#   'BIGEYE': 1,
#   'RED DRUM': 1},
#  '2021-02-15': {'GRAY SNAPPER': 6,
#   'BLACKFIN TUNA': 2,
#   'PINFISH': 2,
#   'ATLANTIC THREAD HERRING': 2,
#   'LITTLE TUNNY': 1,
#   'BLACK SEA BASS': 1,
#   'SPANISH MACKEREL': 1},
#  '2021-02-16': {'VERMILION SNAPPER': 5},
#  '2021-02-17': {'GRAY SNAPPER': 4, 'BLACK DRUM': 2, 'SPOTTED SEATROUT': 2},
#  '2021-02-18': {'GRAY SNAPPER': 5},
#  '2021-02-19': {'SPANISH MACKEREL': 6,
#   'SHEEPSHEAD': 5,
#   'GULF KINGFISH': 3,
#   'NORTHERN KINGFISH': 1},
#  '2021-02-20': {'VERMILION SNAPPER': 29,
#   'PINFISH': 26,
#   'SHEEPSHEAD': 14,
#   'SAND PERCH': 10,
#   'SPANISH MACKEREL': 9,
#   'ATLANTIC THREAD HERRING': 6,
#   'TOMTATE': 5,
#   'RED PORGY': 5,
#   'BANK SEA BASS': 3,
#   'SAND SEATROUT': 2,
#   'BLACK DRUM': 2,
#   'WHITEBONE PORGY': 1,
#   'ALMACO JACK': 1,
#   'GRAY SNAPPER': 1,
#   'BLUE RUNNER': 1},
#  '2021-02-21': {'SHEEPSHEAD': 13,
#   'STRIPED MULLET': 13,
#   'SPOTTED SEATROUT': 10,
#   'RED DRUM': 7,
#   'PINFISH': 6,
#   'LADYFISH': 5,
#   'SAND SEATROUT': 5,
#   'SOUTHERN KINGFISH': 2,
#   'ATLANTIC CROAKER': 1,
#   'GRAY SNAPPER': 1,
#   'BLUEFISH': 1,
#   'BLACK DRUM': 1},
#  '2021-02-22': {'SPOTTED SEATROUT': 5,
#   'BLUEFISH': 2,
#   'BLUE RUNNER': 2,
#   'COMMON SNOOK': 1,
#   'FLORIDA POMPANO': 1,
#   'SPANISH MACKEREL': 1},
#  '2021-02-23': {'SHEEPSHEAD': 9,
#   'ATLANTIC CROAKER': 7,
#   'WHITE GRUNT': 5,
#   'BONNETHEAD': 2,
#   'LANE SNAPPER': 2,
#   'SAND SEATROUT': 2,
#   'SPANISH MACKEREL': 2,
#   'GRAY SNAPPER': 1},
#  '2021-02-24': {'YELLOWTAIL SNAPPER': 3,
#   'COBIA': 2,
#   'RED DRUM': 2,
#   'WHITE GRUNT': 1,
#   'LANE SNAPPER': 1,
#   'GRAY SNAPPER': 1,
#   'DOLPHIN': 1,
#   'WAHOO': 1,
#   'SMOOTH PUFFER': 1,
#   'MUTTON SNAPPER': 1,
#   'BLACK SEA BASS': 1},
#  '2021-02-25': {'WHITE GRUNT': 5,
#   'BLACK SEA BASS': 3,
#   'GRAY SNAPPER': 2,
#   'SAND SEATROUT': 1,
#   'SHEEPSHEAD': 1},
#  '2021-02-26': {'VERMILION SNAPPER': 44,
#   'SHEEPSHEAD': 42,
#   'RED PORGY': 40,
#   'LANE SNAPPER': 21,
#   'SPANISH MACKEREL': 19,
#   'FLORIDA POMPANO': 15,
#   'PINFISH': 14,
#   'WHITE GRUNT': 10,
#   'TOMTATE': 10,
#   'GRAY SNAPPER': 9,
#   'DOLPHIN': 7,
#   'HOGFISH': 6,
#   'BLUEFISH': 6,
#   'SAND PERCH': 5,
#   'LITTLEHEAD PORGY': 4,
#   'BANK SEA BASS': 3,
#   'YELLOW JACK': 3,
#   'RED GROUPER': 3,
#   'KNOBBED PORGY': 2,
#   'YELLOWTAIL SNAPPER': 2},
#  '2021-02-27': {'SHEEPSHEAD': 80,
#   'VERMILION SNAPPER': 25,
#   'SPOTTED SEATROUT': 23,
#   'GRAY SNAPPER': 21,
#   'ALMACO JACK': 14,
#   'GREATER AMBERJACK': 12,
#   'BLACK SEA BASS': 11,
#   'YELLOWTAIL SNAPPER': 10,
#   'GRAY TRIGGERFISH': 8,
#   'SOUTHERN KINGFISH': 8,
#   'RED DRUM': 5,
#   'CERO': 5,
#   'SOUTHERN FLOUNDER': 4,
#   'SPANISH MACKEREL': 4,
#   'MUTTON SNAPPER': 3,
#   'PINFISH': 3,
#   'ATLANTIC CROAKER': 3,
#   'SCAMP': 2,
#   'COBIA': 2,
#   'LITTLEHEAD PORGY': 2},
#  '2021-02-28': {'SPANISH MACKEREL': 71,
#   'WHITE GRUNT': 46,
#   'SHEEPSHEAD': 28,
#   'ATLANTIC CROAKER': 15,
#   'GRAY SNAPPER': 10,
#   'SPOTTED SEATROUT': 9,
#   'RED GROUPER': 8,
#   'DOLPHIN': 8,
#   'FLORIDA POMPANO': 7,
#   'HOGFISH': 6,
#   'PINFISH': 6,
#   'KING MACKEREL': 5,
#   'JOLTHEAD PORGY': 4,
#   'LITTLE TUNNY': 4,
#   'SILVER PERCH': 3,
#   'GULF KINGFISH': 3,
#   'LANE SNAPPER': 3,
#   'KNOBBED PORGY': 3,
#   'SOUTHERN FLOUNDER': 2,
#   'CREVALLE JACK': 2},
#  '2021-03-01': {'SAND SEATROUT': 4, 'SHEEPSHEAD': 2},
#  '2021-03-02': {'SPANISH MACKEREL': 93,
#   'WHITE GRUNT': 77,
#   'GRAY SNAPPER': 42,
#   'SPOTTED SEATROUT': 39,
#   'YELLOWTAIL SNAPPER': 39,
#   'SHEEPSHEAD': 25,
#   'LANE SNAPPER': 19,
#   'KING MACKEREL': 16,
#   'SAND SEATROUT': 11,
#   'LITTLE TUNNY': 11,
#   'LITTLEHEAD PORGY': 8,
#   'CERO': 7,
#   'RED GROUPER': 7,
#   'BLUE CATFISH': 5,
#   'MUTTON SNAPPER': 4,
#   'GREAT BARRACUDA': 4,
#   'BLUE RUNNER': 3,
#   'INSHORE LIZARDFISH': 2,
#   'RED DRUM': 2,
#   'SAND PERCH': 2},
#  '2021-03-03': {'BLUEFISH': 9,
#   'SPANISH MACKEREL': 9,
#   'STRIPED MULLET': 6,
#   'IRISH POMPANO': 2,
#   'COMMON SNOOK': 2,
#   'BLACK MARGATE': 1,
#   'CREVALLE JACK': 1,
#   'SPINNER SHARK': 1},
#  '2021-03-04': {'YELLOWFIN TUNA': 19,
#   'SHEEPSHEAD': 11,
#   'SOUTHERN KINGFISH': 10,
#   'SPOTTED SEATROUT': 4,
#   'BLACKFIN TUNA': 2,
#   'BIGEYE TUNA': 1,
#   'BLACK DRUM': 1},
#  '2021-03-05': {'SHEEPSHEAD': 18,
#   'SPOTTED SEATROUT': 15,
#   'GRAY TRIGGERFISH': 9,
#   'SNOWY GROUPER': 6,
#   'SPANISH MACKEREL': 6,
#   'WHITE CATFISH': 5,
#   'BLUE CATFISH': 4,
#   'FLORIDA POMPANO': 4,
#   'YELLOWEDGE GROUPER': 4,
#   'SOUTHERN KINGFISH': 4,
#   'LITTLE TUNNY': 3,
#   'PERMIT': 2,
#   'CREVALLE JACK': 2,
#   'RED DRUM': 2,
#   'COMMON SNOOK': 1,
#   'BLACKTIP SHARK': 1,
#   'BEARDED BROTULA': 1,
#   'WAHOO': 1,
#   'TILEFISH': 1,
#   'RED PORGY': 1},
#  '2021-03-06': {'GULF KINGFISH': 26,
#   'SHEEPSHEAD': 19,
#   'PINFISH': 15,
#   'VERMILION SNAPPER': 13,
#   'RED PORGY': 12,
#   'GRAY TRIGGERFISH': 11,
#   'SOUTHERN KINGFISH': 9,
#   'YELLOWFIN TUNA': 8,
#   'GRAY SNAPPER': 7,
#   'SPANISH MACKEREL': 5,
#   'FLORIDA POMPANO': 4,
#   'BLACK DRUM': 3,
#   'YELLOWTAIL SNAPPER': 3,
#   'CERO': 3,
#   'RED DRUM': 3,
#   'LITTLE TUNNY': 2,
#   'WHITEBONE PORGY': 2,
#   'BLUEFIN TUNA': 2,
#   'LIONFISH': 2,
#   'BLACKBELLY ROSEFISH': 2},
#  '2021-03-07': {'ATLANTIC COD': 23,
#   'YELLOWTAIL SNAPPER': 13,
#   'STRIPED MULLET': 11,
#   'BLACK CRAPPIE': 10,
#   'YELLOW PERCH': 10,
#   'NORTHERN PUFFER': 6,
#   'GRAY SNAPPER': 6,
#   'BLUE CATFISH': 5,
#   'SPOTTED SEATROUT': 3,
#   'RED DRUM': 3,
#   'SHEEPSHEAD': 3,
#   'PERMIT': 2,
#   'GREAT BARRACUDA': 2,
#   'YELLOWFIN TUNA': 2,
#   'BLUEFIN TUNA': 2,
#   'CERO': 1,
#   'SOUTHERN KINGFISH': 1,
#   'SOUTHERN FLOUNDER': 1,
#   'SAND SEATROUT': 1,
#   'ATLANTIC CROAKER': 1},
#  '2021-03-08': {'GRAY TRIGGERFISH': 10,
#   'RED PORGY': 6,
#   'VERMILION SNAPPER': 5,
#   'BLUEFISH': 1,
#   'COMMON SNOOK': 1},
#  '2021-03-09': {'SHEEPSHEAD': 15,
#   'RED DRUM': 4,
#   'STRIPED MULLET': 4,
#   'BLACK DRUM': 3,
#   'SPANISH MACKEREL': 2,
#   'SOUTHERN FLOUNDER': 1,
#   'PINFISH': 1,
#   'SAND SEATROUT': 1},
#  '2021-03-10': {'SPOTTED SEATROUT': 31,
#   'YELLOWFIN TUNA': 16,
#   'SHEEPSHEAD': 12,
#   'BLACKFIN TUNA': 11,
#   'PINFISH': 10,
#   'BLACK SEA BASS': 10,
#   'WAHOO': 1,
#   'INSHORE LIZARDFISH': 1},
#  '2021-03-11': {'SOUTHERN KINGFISH': 7,
#   'SHEEPSHEAD': 7,
#   'RED DRUM': 4,
#   'BLUEFISH': 3,
#   'YELLOWFIN TUNA': 3,
#   'BLACK SEA BASS': 2,
#   'SPOTTAIL PINFISH': 1,
#   'GULF KINGFISH': 1,
#   'FLORIDA POMPANO': 1},
#  '2021-03-12': {'SHEEPSHEAD': 39,
#   'SPOTTED SEATROUT': 21,
#   'WHITE GRUNT': 20,
#   'RED DRUM': 17,
#   'NORTHERN SNAKEHEAD': 16,
#   'SOUTHERN KINGFISH': 13,
#   'GULF KINGFISH': 12,
#   'BLACK DRUM': 12,
#   'SOUTHERN FLOUNDER': 10,
#   'FLORIDA POMPANO': 6,
#   'SILVER PERCH': 5,
#   'BLACK CRAPPIE': 3,
#   'WHITE PERCH': 3,
#   'GRAY SNAPPER': 2,
#   'SPOTTAIL PINFISH': 2,
#   'BLACK SEA BASS': 2,
#   'BLUE CATFISH': 1,
#   'RED PORGY': 1,
#   'CHANNEL CATFISH': 1},
#  '2021-03-13': {'SOUTHERN KINGFISH': 79,
#   'KING MACKEREL': 48,
#   'SHEEPSHEAD': 45,
#   'SPOTTED SEATROUT': 43,
#   'GULF KINGFISH': 33,
#   'RED DRUM': 25,
#   'SPANISH MACKEREL': 20,
#   'BLUE CATFISH': 18,
#   'BLUE RUNNER': 14,
#   'RED GROUPER': 12,
#   'WHITE PERCH': 11,
#   'MUTTON SNAPPER': 10,
#   'ATLANTIC CROAKER': 10,
#   'WHITEBONE PORGY': 8,
#   'STRIPED MULLET': 8,
#   'PINFISH': 8,
#   'YELLOWTAIL SNAPPER': 7,
#   'LITTLE TUNNY': 6,
#   'BLACK DRUM': 6,
#   'HARDHEAD CATFISH': 5},
#  '2021-03-14': {'KING MACKEREL': 116,
#   'SOUTHERN KINGFISH': 42,
#   'BLUE CATFISH': 36,
#   'SPANISH MACKEREL': 32,
#   'LANE SNAPPER': 28,
#   'YELLOWFIN TUNA': 25,
#   'SHEEPSHEAD': 24,
#   'WHITE GRUNT': 22,
#   'VERMILION SNAPPER': 17,
#   'SPOTTED SEATROUT': 15,
#   'RED PORGY': 14,
#   'GULF KINGFISH': 10,
#   'BALLYHOO': 10,
#   'GRAY SNAPPER': 10,
#   'FLORIDA POMPANO': 9,
#   'GRAY TRIGGERFISH': 9,
#   'RED DRUM': 8,
#   'ATLANTIC CROAKER': 8,
#   'YELLOWTAIL SNAPPER': 7,
#   'SAND SEATROUT': 7},
#  '2021-03-15': {'VERMILION SNAPPER': 61,
#   'SHEEPSHEAD': 27,
#   'TOMTATE': 16,
#   'SPANISH MACKEREL': 16,
#   'RED DRUM': 12,
#   'DOLPHIN': 7,
#   'SAND SEATROUT': 7,
#   'SPOTTED SEATROUT': 4,
#   'WHITE GRUNT': 3,
#   'FLORIDA POMPANO': 2,
#   'SOUTHERN FLOUNDER': 2,
#   'BLACK DRUM': 1,
#   'SOUTHERN KINGFISH': 1,
#   'KING MACKEREL': 1,
#   'GRAY SNAPPER': 1,
#   'WAHOO': 1,
#   'ATLANTIC CROAKER': 1},
#  '2021-03-16': {'SPOTTED SEATROUT': 8},
#  '2021-03-17': {'BLACKFIN TUNA': 11,
#   'SOUTHERN KINGFISH': 11,
#   'GRAY SNAPPER': 11,
#   'LITTLE TUNNY': 9,
#   'DOLPHIN': 3,
#   'FRIGATE MACKEREL': 1,
#   'SPANISH MACKEREL': 1,
#   'BLUE RUNNER': 1,
#   'SPOTTED SEATROUT': 1},
#  '2021-03-18': {'SPOTTED SEATROUT': 8,
#   'SHEEPSHEAD': 8,
#   'SOUTHERN KINGFISH': 7,
#   'RED DRUM': 6,
#   'PINFISH': 6,
#   'BLACK DRUM': 3,
#   'TAUTOG': 1},
#  '2021-03-19': {'SPANISH MACKEREL': 16,
#   'SPOTTED SEATROUT': 11,
#   'SOUTHERN KINGFISH': 10,
#   'SHEEPSHEAD': 8,
#   'GULF KINGFISH': 6,
#   'BLACKFIN TUNA': 4,
#   'GREAT BARRACUDA': 4,
#   'BLACKFIN SNAPPER': 4,
#   'SOUTHERN FLOUNDER': 4,
#   'RED DRUM': 3,
#   'FLORIDA POMPANO': 2,
#   'LITTLE TUNNY': 1,
#   'DOLPHIN': 1,
#   'BLACK DRUM': 1,
#   'GRAY TRIGGERFISH': 1},
#  '2021-03-20': {'VERMILION SNAPPER': 72,
#   'SHEEPSHEAD': 43,
#   'RED PORGY': 24,
#   'SPANISH MACKEREL': 19,
#   'BLACKFIN TUNA': 17,
#   'YELLOWTAIL SNAPPER': 17,
#   'GRAY SNAPPER': 15,
#   'KING MACKEREL': 14,
#   'BLUE CATFISH': 12,
#   'RED DRUM': 12,
#   'WHITE GRUNT': 10,
#   'DOLPHIN': 9,
#   'RED HAKE': 8,
#   'GRAY TRIGGERFISH': 7,
#   'ATLANTIC CROAKER': 5,
#   'FINETOOTH SHARK': 5,
#   'FLORIDA POMPANO': 5,
#   'ATLANTIC COD': 4,
#   'LANE SNAPPER': 4,
#   'CERO': 4},
#  '2021-03-21': {'SHEEPSHEAD': 20,
#   'RED DRUM': 19,
#   'PINFISH': 18,
#   'CHANNEL CATFISH': 12,
#   'SAND SEATROUT': 9,
#   'GRAY SNAPPER': 8,
#   'SOUTHERN KINGFISH': 8,
#   'STRIPED MULLET': 5,
#   'BLUE CATFISH': 5,
#   'YELLOWFIN TUNA': 4,
#   'BLACKFIN TUNA': 4,
#   'BLUE RUNNER': 2,
#   'SPOTTED SEATROUT': 2,
#   'SPANISH MACKEREL': 2,
#   'DOG SNAPPER': 1,
#   'BLUESTRIPED GRUNT': 1,
#   'SOUTHERN FLOUNDER': 1,
#   'SAILORS CHOICE': 1,
#   'MUTTON SNAPPER': 1},
#  '2021-03-22': {'SOUTHERN KINGFISH': 20,
#   'YELLOWTAIL SNAPPER': 19,
#   'PINFISH': 7,
#   'SPANISH MACKEREL': 3,
#   'ATLANTIC SPADEFISH': 3,
#   'HARDHEAD CATFISH': 3,
#   'BLUEFISH': 2,
#   'BLUE CATFISH': 2,
#   'SHEEPSHEAD': 1,
#   'COMMON SNOOK': 1,
#   'FLORIDA POMPANO': 1,
#   'LANE SNAPPER': 1},
#  '2021-03-23': {'PINFISH': 25,
#   'SPANISH MACKEREL': 21,
#   'BLUE RUNNER': 14,
#   'SPOTTED SEATROUT': 10,
#   'LITTLE TUNNY': 10,
#   'SILK SNAPPER': 9,
#   'GULF KINGFISH': 5,
#   'ATLANTIC CROAKER': 4,
#   'RED DRUM': 3,
#   'SHEEPSHEAD': 2,
#   'SOUTHERN KINGFISH': 2,
#   'KING MACKEREL': 2,
#   'GREAT BARRACUDA': 2,
#   'MUTTON SNAPPER': 1,
#   'SAND SEATROUT': 1},
#  '2021-03-24': {'SPANISH MACKEREL': 51,
#   'WHITE GRUNT': 49,
#   'KING MACKEREL': 31,
#   'HOGFISH': 3,
#   'SAND PERCH': 2,
#   'LITTLE TUNNY': 2,
#   'SOUTHERN PUFFER': 1},
#  '2021-03-25': {'YELLOWFIN TUNA': 33,
#   'BLACKFIN TUNA': 19,
#   'SHEEPSHEAD': 15,
#   'SPOTTED SEATROUT': 10,
#   'GREATER AMBERJACK': 6,
#   'LITTLE TUNNY': 5,
#   'GRAY SNAPPER': 3,
#   'ATLANTIC SHARPNOSE SHARK': 3,
#   'DOLPHIN': 2,
#   'NORTHERN PUFFER': 2},
#  '2021-03-26': {'SPANISH MACKEREL': 61,
#   'SHEEPSHEAD': 44,
#   'ATLANTIC HERRING': 23,
#   'RED DRUM': 15,
#   'LITTLE TUNNY': 15,
#   'SOUTHERN KINGFISH': 11,
#   'KING MACKEREL': 11,
#   'ATLANTIC CROAKER': 10,
#   'BLACK SEA BASS': 9,
#   'BLACK DRUM': 8,
#   'GULF KINGFISH': 8,
#   'BLUEFISH': 8,
#   'SPOTTED SEATROUT': 7,
#   'SPOTTAIL PINFISH': 5,
#   'BLUE RUNNER': 3,
#   'COWNOSE RAY': 3,
#   'FLORIDA POMPANO': 3,
#   'GRAY SNAPPER': 3,
#   'WHITEBONE PORGY': 2,
#   'NORTHERN SNAKEHEAD': 2},
#  '2021-03-27': {'SPOTTED SEATROUT': 75,
#   'BLUE CATFISH': 53,
#   'KING MACKEREL': 42,
#   'SPANISH MACKEREL': 36,
#   'RED DRUM': 27,
#   'SHEEPSHEAD': 25,
#   'ATLANTIC HERRING': 24,
#   'SOUTHERN KINGFISH': 22,
#   'YELLOWFIN TUNA': 19,
#   'WHITE PERCH': 16,
#   'ATLANTIC CROAKER': 15,
#   'GRAY SNAPPER': 14,
#   'BLACK DRUM': 12,
#   'BLACKFIN TUNA': 10,
#   'LITTLE TUNNY': 10,
#   'VERMILION SNAPPER': 9,
#   'GULF KINGFISH': 9,
#   'PINFISH': 7,
#   'BLACK SEA BASS': 7,
#   'NORTHERN PUFFER': 7},
#  '2021-03-28': {'SPANISH MACKEREL': 84,
#   'SOUTHERN KINGFISH': 75,
#   'SPOTTED SEATROUT': 35,
#   'SHEEPSHEAD': 27,
#   'RED GROUPER': 25,
#   'GRAY SNAPPER': 23,
#   'BLUE CATFISH': 19,
#   'LANE SNAPPER': 19,
#   'ATLANTIC THREAD HERRING': 17,
#   'CREVALLE JACK': 11,
#   'KING MACKEREL': 11,
#   'WHITE GRUNT': 11,
#   'GULF KINGFISH': 10,
#   'PINFISH': 9,
#   'BLUE RUNNER': 9,
#   'SAND SEATROUT': 9,
#   'RED DRUM': 6,
#   'BLACK SEA BASS': 5,
#   'FLORIDA POMPANO': 4,
#   'BLACK DRUM': 4},
#  '2021-03-29': {'SPOTTED SEATROUT': 12,
#   'SAND SEATROUT': 11,
#   'SOUTHERN KINGFISH': 4,
#   'GRAY SNAPPER': 2,
#   'RED DRUM': 2,
#   'SOUTHERN FLOUNDER': 1,
#   'SPOT': 1,
#   'SHEEPSHEAD': 1,
#   'BONNETHEAD': 1,
#   'PINFISH': 1},
#  '2021-03-30': {'VERMILION SNAPPER': 54,
#   'RED PORGY': 42,
#   'GRAY TRIGGERFISH': 19,
#   'SPANISH MACKEREL': 13,
#   'GRAY SNAPPER': 10,
#   'YELLOWFIN TUNA': 7,
#   'SPINY DOGFISH': 5,
#   'RED DRUM': 4,
#   'BLACK DRUM': 4,
#   'GULF FLOUNDER': 4,
#   'WHITEBONE PORGY': 3,
#   'SHEEPSHEAD': 3,
#   'SOUTHERN FLOUNDER': 3,
#   'SAND SEATROUT': 2,
#   'BLACK SEA BASS': 2,
#   'SPOTTED SEATROUT': 2,
#   'LITTLE TUNNY': 2,
#   'ATLANTIC CROAKER': 1,
#   'FLORIDA POMPANO': 1,
#   'GULF KINGFISH': 1},
#  '2021-03-31': {'YELLOWFIN TUNA': 25,
#   'SPANISH MACKEREL': 9,
#   'PINFISH': 6,
#   'SPOTTED SEATROUT': 6,
#   'SOUTHERN KINGFISH': 5,
#   'VERMILION SNAPPER': 5,
#   'GRAY TRIGGERFISH': 3,
#   'SHEEPSHEAD': 3,
#   'BLUEFISH': 3,
#   'BLACK SEA BASS': 3,
#   'WAHOO': 3,
#   'WEAKFISH': 2,
#   'BLACKFIN TUNA': 2,
#   'ATLANTIC CROAKER': 1,
#   'GRAY SNAPPER': 1,
#   'DOLPHIN': 1,
#   'CREVALLE JACK': 1},
#  '2021-04-01': {'SHEEPSHEAD': 6,
#   'SAND SEATROUT': 4,
#   'SOUTHERN KINGFISH': 1,
#   'KING MACKEREL': 1},
#  '2021-04-02': {'SPANISH MACKEREL': 44,
#   'SPOTTED SEATROUT': 8,
#   'SHEEPSHEAD': 6,
#   'GRAY SNAPPER': 6,
#   'YELLOWTAIL SNAPPER': 4,
#   'BLACK DRUM': 3,
#   'HARDHEAD CATFISH': 3,
#   'LITTLE TUNNY': 2,
#   'LANE SNAPPER': 2,
#   'NORTHERN PUFFER': 2,
#   'MUTTON SNAPPER': 2,
#   'GAFFTOPSAIL CATFISH': 1,
#   'FLORIDA POMPANO': 1,
#   'GULF FLOUNDER': 1,
#   'GULF KINGFISH': 1,
#   'PINFISH': 1,
#   'SOUTHERN FLOUNDER': 1},
#  '2021-04-03': {'RED PORGY': 47,
#   'VERMILION SNAPPER': 44,
#   'ROUND SCAD': 30,
#   'GRAY TRIGGERFISH': 21,
#   'SHEEPSHEAD': 20,
#   'SOUTHERN KINGFISH': 12,
#   'BLUE CATFISH': 12,
#   'PINFISH': 11,
#   'SPOTTED SEATROUT': 10,
#   'ATLANTIC CROAKER': 10,
#   'SAND SEATROUT': 8,
#   'BLACK DRUM': 7,
#   'STRIPED BASS': 6,
#   'HARDHEAD CATFISH': 5,
#   'GRAY SNAPPER': 5,
#   'SOUTHERN FLOUNDER': 2,
#   'WHITEBONE PORGY': 2,
#   'STRIPED MULLET': 2,
#   'ATLANTIC STINGRAY': 1,
#   'BLUEFISH': 1},
#  '2021-04-04': {'SPANISH MACKEREL': 94,
#   'SOUTHERN KINGFISH': 31,
#   'SHEEPSHEAD': 26,
#   'SILVER PERCH': 8,
#   'ATLANTIC CROAKER': 8,
#   'SPOTTED SEATROUT': 7,
#   'KING MACKEREL': 7,
#   'BLACK SEA BASS': 7,
#   'RED GROUPER': 6,
#   'YELLOWFIN TUNA': 5,
#   'NORTHERN PUFFER': 5,
#   'BLUEFISH': 5,
#   'WHITE GRUNT': 4,
#   'LITTLE TUNNY': 4,
#   'FLORIDA POMPANO': 4,
#   'ROUND SCAD': 4,
#   'TAUTOG': 4,
#   'WEAKFISH': 4,
#   'SOUTHERN FLOUNDER': 3,
#   'BLUE RUNNER': 3},
#  '2021-04-05': {'SOUTHERN KINGFISH': 18,
#   'ATLANTIC CROAKER': 15,
#   'BLUE CATFISH': 15,
#   'LITTLE TUNNY': 10,
#   'BLUEFISH': 8,
#   'ATLANTIC BONITO': 7,
#   'SHEEPSHEAD': 6,
#   'BLACKFIN TUNA': 6,
#   'SPOTTED SEATROUT': 4,
#   'ALMACO JACK': 3,
#   'BLACK DRUM': 3,
#   'GULF KINGFISH': 2,
#   'RED DRUM': 2,
#   'SPANISH MACKEREL': 2,
#   'SILVER SEATROUT': 1,
#   'YELLOW PERCH': 1,
#   'TOMTATE': 1,
#   'SPOTTAIL PINFISH': 1,
#   'NORTHERN KINGFISH': 1,
#   'SILVER PERCH': 1},
#  '2021-04-06': {'SOUTHERN KINGFISH': 15,
#   'BLACK SEA BASS': 10,
#   'SPANISH MACKEREL': 10,
#   'SPOTTED SEATROUT': 8,
#   'SHEEPSHEAD': 8,
#   'ATLANTIC CROAKER': 8,
#   'RED DRUM': 4,
#   'SPOTTAIL PINFISH': 2,
#   'BLUEFISH': 2,
#   'MUTTON SNAPPER': 2,
#   'PINFISH': 1,
#   'SAND SEATROUT': 1,
#   'STRIPED BASS': 1,
#   'NORTHERN PUFFER': 1,
#   'TAUTOG': 1,
#   'COBIA': 1,
#   'HARDHEAD CATFISH': 1},
#  '2021-04-07': {'SOUTHERN KINGFISH': 95,
#   'VERMILION SNAPPER': 34,
#   'TOMTATE': 12,
#   'YELLOWTAIL SNAPPER': 11,
#   'RED DRUM': 9,
#   'BLACK DRUM': 8,
#   'ATLANTIC CROAKER': 7,
#   'KING MACKEREL': 7,
#   'LANE SNAPPER': 6,
#   'DOLPHIN': 6,
#   'GRAY TRIGGERFISH': 5,
#   'GRAY SNAPPER': 5,
#   'SPANISH MACKEREL': 4,
#   'LITTLE TUNNY': 4,
#   'WHITE GRUNT': 3,
#   'RED PORGY': 3,
#   'JOLTHEAD PORGY': 3,
#   'SAND PERCH': 3,
#   'BLUEFISH': 2,
#   'YELLOWFIN TUNA': 2},
#  '2021-04-08': {'SPOTTED SEATROUT': 23,
#   'BLACK SEA BASS': 19,
#   'SPANISH MACKEREL': 16,
#   'GRAY SNAPPER': 13,
#   'RED DRUM': 8,
#   'WHITE GRUNT': 8,
#   'BLUE RUNNER': 7,
#   'KING MACKEREL': 7,
#   'ROCK SEA BASS': 7,
#   'SOUTHERN KINGFISH': 7,
#   'SPOTTAIL PINFISH': 5,
#   'SAND SEATROUT': 5,
#   'BANK SEA BASS': 3,
#   'WHITEBONE PORGY': 2,
#   'BLACK DRUM': 2,
#   'SKIPJACK TUNA': 2,
#   'YELLOWFIN TUNA': 2,
#   'SAND PERCH': 1,
#   'BLUEFISH': 1,
#   'SHEEPSHEAD': 1},
#  '2021-04-09': {'SPOTTED SEATROUT': 66,
#   'KING MACKEREL': 49,
#   'YELLOWFIN TUNA': 40,
#   'SPANISH MACKEREL': 31,
#   'RED DRUM': 29,
#   'DOLPHIN': 16,
#   'ATLANTIC MENHADEN': 15,
#   'BLACKFIN TUNA': 14,
#   'SOUTHERN KINGFISH': 12,
#   'ATLANTIC CROAKER': 8,
#   'YELLOWTAIL SNAPPER': 8,
#   'LITTLE TUNNY': 8,
#   'SPOT': 7,
#   'WHITE PERCH': 7,
#   'GRAY TRIGGERFISH': 6,
#   'GREATER AMBERJACK': 5,
#   'BLUEFISH': 5,
#   'BLACK DRUM': 4,
#   'SHEEPSHEAD': 3,
#   'BLACKTIP SHARK': 2},
#  '2021-04-10': {'SOUTHERN KINGFISH': 107,
#   'SPOTTED SEATROUT': 43,
#   'RED DRUM': 24,
#   'TAUTOG': 21,
#   'PINFISH': 10,
#   'SPANISH MACKEREL': 10,
#   'WHITE PERCH': 9,
#   'ATLANTIC CROAKER': 6,
#   'BLUE CATFISH': 5,
#   'SOUTHERN FLOUNDER': 5,
#   'BLUE RUNNER': 5,
#   'SPINY DOGFISH': 5,
#   'GREAT BARRACUDA': 5,
#   'BERMUDA CHUB': 4,
#   'GRAY SNAPPER': 3,
#   'SAILORS CHOICE': 3,
#   'BLACK MARGATE': 3,
#   'BLUESTRIPED GRUNT': 2,
#   'SILVER PERCH': 2,
#   'COMMON SNOOK': 2},
#  '2021-04-11': {'SPANISH MACKEREL': 16,
#   'BLACK DRUM': 14,
#   'GULF KINGFISH': 11,
#   'SAND SEATROUT': 11,
#   'YELLOWFIN TUNA': 11,
#   'ATLANTIC CROAKER': 10,
#   'SHEEPSHEAD': 10,
#   'BLACK CRAPPIE': 8,
#   'RED DRUM': 8,
#   'SOUTHERN KINGFISH': 6,
#   'TOMTATE': 5,
#   'LITTLE TUNNY': 4,
#   'SOUTHERN FLOUNDER': 3,
#   'ATLANTIC SHARPNOSE SHARK': 2,
#   'BLUE CATFISH': 2,
#   'CHANNEL CATFISH': 2,
#   'SPOTTED SEATROUT': 1,
#   'SILVER PERCH': 1,
#   'DOLPHIN': 1,
#   'WAHOO': 1},
#  '2021-04-12': {'SOUTHERN KINGFISH': 18,
#   'BLACK DRUM': 15,
#   'GULF KINGFISH': 10,
#   'BLUE CATFISH': 9,
#   'WHITE PERCH': 7,
#   'SAND SEATROUT': 6,
#   'GRAY SNAPPER': 6,
#   'SHEEPSHEAD': 6,
#   'TAUTOG': 6,
#   'SOUTHERN FLOUNDER': 5,
#   'RED DRUM': 5,
#   'NORTHERN KINGFISH': 5,
#   'SPOTTED SEATROUT': 2,
#   'LITTLE TUNNY': 2,
#   'YELLOWTAIL SNAPPER': 2,
#   'RAINBOW RUNNER': 2,
#   'KING MACKEREL': 2,
#   'JOLTHEAD PORGY': 2,
#   'UNICORN FILEFISH': 2,
#   'SAILORS CHOICE': 2},
#  '2021-04-13': {'ATLANTIC THREAD HERRING': 15,
#   'PINFISH': 14,
#   'SPANISH MACKEREL': 11,
#   'LADYFISH': 8,
#   'WHITE GRUNT': 8,
#   'BLUE CATFISH': 6,
#   'LANE SNAPPER': 5,
#   'GRAY TRIGGERFISH': 4,
#   'KING MACKEREL': 2,
#   'BLACKFIN TUNA': 1,
#   'YELLOWTAIL SNAPPER': 1,
#   'GRAY SNAPPER': 1,
#   'SHEEPSHEAD': 1},
#  '2021-04-14': {'SOUTHERN KINGFISH': 34,
#   'YELLOWFIN TUNA': 12,
#   'NORTHERN PUFFER': 10,
#   'ATLANTIC CROAKER': 6,
#   'SPOTTED SEATROUT': 5,
#   'ATLANTIC BONITO': 3,
#   'SPANISH MACKEREL': 2,
#   'RED DRUM': 2,
#   'SOUTHERN FLOUNDER': 1},
#  '2021-04-15': {'SPOTTED SEATROUT': 20,
#   'LANE SNAPPER': 17,
#   'RED GROUPER': 15,
#   'SOUTHERN KINGFISH': 12,
#   'COMMON SNOOK': 11,
#   'ATLANTIC SPADEFISH': 10,
#   'WHITE GRUNT': 10,
#   'BLUEFISH': 7,
#   'GRAY SNAPPER': 6,
#   'SCAMP': 6,
#   'ROCK HIND': 5,
#   'HOGFISH': 5,
#   'WEAKFISH': 3,
#   'RED DRUM': 3,
#   'LITTLEHEAD PORGY': 2,
#   'NORTHERN PUFFER': 2,
#   'VERMILION SNAPPER': 1},
#  '2021-04-16': {'YELLOWTAIL SNAPPER': 25,
#   'SPOTTED SEATROUT': 20,
#   'BLACKFIN TUNA': 13,
#   'CREVALLE JACK': 10,
#   'DOLPHIN': 9,
#   'SOUTHERN KINGFISH': 9,
#   'FLORIDA POMPANO': 8,
#   'LITTLE TUNNY': 7,
#   'GRAY SNAPPER': 6,
#   'GULF KINGFISH': 6,
#   'BLACKBELLY ROSEFISH': 5,
#   'RED DRUM': 3,
#   'TAUTOG': 3,
#   'SPANISH MACKEREL': 2,
#   'BONNETHEAD': 2,
#   'ATLANTIC SHARPNOSE SHARK': 2,
#   'NORTHERN PUFFER': 2,
#   'KING MACKEREL': 2,
#   'MUTTON SNAPPER': 1,
#   'WAHOO': 1},
#  '2021-04-17': {'VERMILION SNAPPER': 81,
#   'RED PORGY': 59,
#   'YELLOWFIN TUNA': 58,
#   'SPANISH MACKEREL': 47,
#   'SAND SEATROUT': 41,
#   'SOUTHERN KINGFISH': 34,
#   'GRAY TRIGGERFISH': 33,
#   'GRAY SNAPPER': 29,
#   'SPOTTED SEATROUT': 27,
#   'SHEEPSHEAD': 22,
#   'TAUTOG': 18,
#   'BLACKFIN TUNA': 13,
#   'BLACK SEA BASS': 12,
#   'ATLANTIC CROAKER': 11,
#   'SAILORS CHOICE': 11,
#   'BLUE CATFISH': 10,
#   'LITTLE TUNNY': 9,
#   'JOLTHEAD PORGY': 8,
#   'BLUEFISH': 7,
#   'CREVALLE JACK': 7},
#  '2021-04-18': {'VERMILION SNAPPER': 38,
#   'GRAY SNAPPER': 37,
#   'YELLOWFIN TUNA': 35,
#   'BLACK SEA BASS': 27,
#   'TAUTOG': 21,
#   'WHITE PERCH': 21,
#   'BLACKFIN TUNA': 19,
#   'BLUE CATFISH': 15,
#   'SPOTTED SEATROUT': 14,
#   'LITTLE TUNNY': 12,
#   'REDTAIL SCAD': 6,
#   'DOLPHIN': 6,
#   'SPOTTAIL PINFISH': 6,
#   'GRAY TRIGGERFISH': 5,
#   'SPANISH MACKEREL': 5,
#   'TOMTATE': 5,
#   'GREAT BARRACUDA': 5,
#   'RED PORGY': 5,
#   'YELLOWTAIL SNAPPER': 5,
#   'SAND SEATROUT': 4},
#  '2021-04-19': {'NORTHERN PUFFER': 33,
#   'YELLOWTAIL SNAPPER': 14,
#   'YELLOWFIN TUNA': 12,
#   'SPOTTED SEATROUT': 7,
#   'BLACK SEA BASS': 7,
#   'GRAY SNAPPER': 5,
#   'RED DRUM': 4,
#   'BLACKFIN TUNA': 2,
#   'FLORIDA POMPANO': 2,
#   'PINFISH': 2,
#   'NORTHERN SNAKEHEAD': 1,
#   'RED PORGY': 1},
#  '2021-04-20': {'SOUTHERN KINGFISH': 47,
#   'YELLOWFIN TUNA': 24,
#   'SPOTTED SEATROUT': 17,
#   'CHANNEL CATFISH': 17,
#   'SPANISH MACKEREL': 12,
#   'HADDOCK': 10,
#   'SAND SEATROUT': 8,
#   'BLUE CATFISH': 8,
#   'BLUEFISH': 3,
#   'STRIPED BASS': 3,
#   'BLACKFIN TUNA': 2,
#   'SPOT': 2,
#   'SILVER PERCH': 2,
#   'WAHOO': 2,
#   'KING MACKEREL': 1,
#   'DOLPHIN': 1,
#   'LITTLE TUNNY': 1,
#   'AMERICAN EEL': 1,
#   'WHITE CATFISH': 1,
#   'RED DRUM': 1},
#  '2021-04-21': {'YELLOWFIN TUNA': 16,
#   'SPANISH MACKEREL': 15,
#   'DOLPHIN': 10,
#   'WAHOO': 8,
#   'BLACKFIN TUNA': 7,
#   'BLACK DRUM': 7,
#   'BLACKBELLY ROSEFISH': 7,
#   'RED DRUM': 7,
#   'YELLOWTAIL SNAPPER': 5,
#   'KING MACKEREL': 5,
#   'LITTLE TUNNY': 5,
#   'VERMILION SNAPPER': 4,
#   'ATLANTIC BONITO': 3,
#   'GREAT BARRACUDA': 2,
#   'SOUTHERN KINGFISH': 2,
#   'TOMTATE': 2,
#   'MUTTON SNAPPER': 2,
#   'SOUTHERN FLOUNDER': 1,
#   'FLORIDA POMPANO': 1,
#   'COBIA': 1},
#  '2021-04-22': {'SOUTHERN KINGFISH': 39,
#   'WHITE GRUNT': 25,
#   'PIGFISH': 17,
#   'VERMILION SNAPPER': 13,
#   'SPANISH MACKEREL': 10,
#   'RED PORGY': 6,
#   'WEAKFISH': 4,
#   'SILVER PERCH': 4,
#   'BLUEFISH': 4,
#   'LITTLEHEAD PORGY': 4,
#   'PINFISH': 4,
#   'RED DRUM': 1,
#   'SPOTTED SEATROUT': 1,
#   'GRAY TRIGGERFISH': 1,
#   'GULF FLOUNDER': 1,
#   'FLORIDA POMPANO': 1,
#   'SOUTHERN FLOUNDER': 1},
#  '2021-04-23': {'SPOTTED SEATROUT': 41,
#   'SPANISH MACKEREL': 40,
#   'BLACK SEA BASS': 32,
#   'SPOTTAIL PINFISH': 19,
#   'SOUTHERN KINGFISH': 19,
#   'GRAY TRIGGERFISH': 19,
#   'VERMILION SNAPPER': 19,
#   'GRAY SNAPPER': 17,
#   'SHEEPSHEAD': 13,
#   'BLACKFIN TUNA': 13,
#   'RED DRUM': 12,
#   'WHITE GRUNT': 8,
#   'DOLPHIN': 6,
#   'SKIPJACK TUNA': 6,
#   'STRIPED BASS': 6,
#   'BLUEFISH': 5,
#   'YELLOWTAIL SNAPPER': 5,
#   'GAG': 5,
#   'GAFFTOPSAIL CATFISH': 5,
#   'SAND PERCH': 5},
#  '2021-04-24': {'TAUTOG': 54,
#   'DOLPHIN': 41,
#   'YELLOWTAIL SNAPPER': 39,
#   'SPANISH MACKEREL': 34,
#   'BLACKFIN TUNA': 22,
#   'LITTLE TUNNY': 22,
#   'GRAY TRIGGERFISH': 19,
#   'STRIPED BASS': 17,
#   'SPOTTED SEATROUT': 14,
#   'KING MACKEREL': 10,
#   'WAHOO': 9,
#   'BLUEFISH': 8,
#   'BLACK DRUM': 7,
#   'FLORIDA POMPANO': 7,
#   'GRAY SNAPPER': 7,
#   'RED DRUM': 6,
#   'SHEEPSHEAD': 6,
#   'PINFISH': 6,
#   'SUMMER FLOUNDER': 5,
#   'SOUTHERN FLOUNDER': 4},
#  '2021-04-25': {'SOUTHERN KINGFISH': 44,
#   'SPOTTED SEATROUT': 20,
#   'BLUE RUNNER': 15,
#   'ATLANTIC CROAKER': 13,
#   'RED DRUM': 12,
#   'ATLANTIC SHARPNOSE SHARK': 10,
#   'TAUTOG': 7,
#   'BLUEFISH': 5,
#   'LITTLE TUNNY': 5,
#   'CHANNEL CATFISH': 5,
#   'WHITE PERCH': 5,
#   'SPANISH MACKEREL': 2,
#   'KING MACKEREL': 2,
#   'BLACK DRUM': 2,
#   'LADYFISH': 2,
#   'SOUTHERN FLOUNDER': 2,
#   'GRAY TRIGGERFISH': 1,
#   'CERO': 1,
#   'STRIPED BASS': 1,
#   'HARDHEAD CATFISH': 1},
#  '2021-04-26': {'DOLPHIN': 27,
#   'SPANISH MACKEREL': 18,
#   'SOUTHERN KINGFISH': 17,
#   'SPOTTED SEATROUT': 11,
#   'BLACK DRUM': 10,
#   'SOUTHERN FLOUNDER': 8,
#   'RED DRUM': 6,
#   'SHEEPSHEAD': 6,
#   'FLORIDA POMPANO': 6,
#   'PIGFISH': 6,
#   'LANE SNAPPER': 5,
#   'ATLANTIC CROAKER': 5,
#   'RED GROUPER': 5,
#   'BLACKFIN TUNA': 4,
#   'WEAKFISH': 3,
#   'WAHOO': 2,
#   'YELLOWFIN TUNA': 1,
#   'PINFISH': 1,
#   'BLACK SEA BASS': 1,
#   'KING MACKEREL': 1},
#  '2021-04-27': {'SOUTHERN KINGFISH': 52,
#   'SPANISH MACKEREL': 29,
#   'RED DRUM': 13,
#   'ATLANTIC SPADEFISH': 7,
#   'FLORIDA POMPANO': 6,
#   'PINFISH': 5,
#   'TAUTOG': 4,
#   'DOLPHIN': 4,
#   'SPOTTED SEATROUT': 3,
#   'BLACKFIN TUNA': 3,
#   'ATLANTIC BONITO': 3,
#   'SHEEPSHEAD': 3,
#   'COMMON SNOOK': 2,
#   'GAFFTOPSAIL CATFISH': 2,
#   'SAND PERCH': 2,
#   'BLUEFISH': 2,
#   'GRAY SNAPPER': 1,
#   'KING MACKEREL': 1,
#   'YELLOWFIN TUNA': 1,
#   'SOUTHERN FLOUNDER': 1},
#  '2021-04-28': {'SPANISH MACKEREL': 16,
#   'BLUEFISH': 10,
#   'RED DRUM': 5,
#   'PINFISH': 5,
#   'SPOTTED SEATROUT': 4,
#   'RED HAKE': 3,
#   'CUNNER': 2,
#   'YELLOWTAIL SNAPPER': 2,
#   'MUTTON SNAPPER': 2,
#   'ATLANTIC MENHADEN': 2,
#   'ATLANTIC COD': 2,
#   'DOLPHIN': 2,
#   'LANE SNAPPER': 1,
#   'SAILORS CHOICE': 1,
#   'WEAKFISH': 1,
#   'LITTLE TUNNY': 1,
#   'YELLOWFIN TUNA': 1,
#   'KING MACKEREL': 1,
#   'STRIPED BASS': 1},
#  '2021-04-29': {'SPANISH MACKEREL': 50,
#   'SCUP': 23,
#   'BLACKFIN TUNA': 13,
#   'GULF KINGFISH': 12,
#   'SOUTHERN KINGFISH': 11,
#   'VERMILION SNAPPER': 10,
#   'ATLANTIC BONITO': 7,
#   'DOLPHIN': 7,
#   'SHEEPSHEAD': 5,
#   'ATLANTIC CROAKER': 5,
#   'BLUEFISH': 5,
#   'BLACK DRUM': 4,
#   'BLACK SEA BASS': 3,
#   'STRIPED MULLET': 3,
#   'GRAY TRIGGERFISH': 3,
#   'SPOTTED SEATROUT': 3,
#   'GRAY SNAPPER': 3,
#   'SOUTHERN FLOUNDER': 3,
#   'GREAT BARRACUDA': 1,
#   'FLORIDA POMPANO': 1},
#  '2021-04-30': {'SPOTTED SEATROUT': 67,
#   'HADDOCK': 40,
#   'SPANISH MACKEREL': 30,
#   'COMMON SNOOK': 20,
#   'SOUTHERN KINGFISH': 19,
#   'FLORIDA POMPANO': 16,
#   'GRAY SNAPPER': 15,
#   'RED DRUM': 13,
#   'WHITE GRUNT': 10,
#   'PIGFISH': 8,
#   'DOLPHIN': 7,
#   'BLUEFISH': 6,
#   'PINFISH': 6,
#   'ATLANTIC CROAKER': 6,
#   'SOUTHERN FLOUNDER': 5,
#   'GULF KINGFISH': 5,
#   'WHITE PERCH': 5,
#   'SHEEPSHEAD': 3,
#   'HOUNDFISH': 3,
#   'YELLOW JACK': 2},
#  '2021-05-01': {'SOUTHERN KINGFISH': 44,
#   'SPOTTED SEATROUT': 39,
#   'ATLANTIC CROAKER': 33,
#   'GRAY SNAPPER': 28,
#   'SAND SEATROUT': 27,
#   'DOLPHIN': 22,
#   'RED DRUM': 20,
#   'YELLOWTAIL SNAPPER': 18,
#   'KING MACKEREL': 17,
#   'TAUTOG': 16,
#   'SPANISH MACKEREL': 15,
#   'LANE SNAPPER': 14,
#   'VERMILION SNAPPER': 14,
#   'GREATER AMBERJACK': 14,
#   'RED GROUPER': 11,
#   'PINFISH': 10,
#   'GRAY TRIGGERFISH': 9,
#   'GAFFTOPSAIL CATFISH': 9,
#   'BLACK DRUM': 7,
#   'WHITE PERCH': 7},
#  '2021-05-02': {'SOUTHERN KINGFISH': 61,
#   'SPOTTED SEATROUT': 36,
#   'SPANISH MACKEREL': 23,
#   'DOLPHIN': 15,
#   'BLUEFISH': 15,
#   'STRIPED BASS': 13,
#   'BLUE CATFISH': 13,
#   'VERMILION SNAPPER': 12,
#   'RED DRUM': 12,
#   'ATLANTIC MENHADEN': 12,
#   'YELLOWTAIL SNAPPER': 9,
#   'SCUP': 8,
#   'NORTHERN SNAKEHEAD': 8,
#   'GREATER AMBERJACK': 7,
#   'GRAY SNAPPER': 6,
#   'LITTLE TUNNY': 6,
#   'RED PORGY': 6,
#   'SHEEPSHEAD': 5,
#   'GULF KINGFISH': 5,
#   'KING MACKEREL': 5},
#  '2021-05-03': {'STRIPED BASS': 17,
#   'SPOTTED SEATROUT': 14,
#   'KING MACKEREL': 10,
#   'DOLPHIN': 6,
#   'SPANISH MACKEREL': 4,
#   'SHEEPSHEAD': 3,
#   'RED DRUM': 2,
#   'BLACK DRUM': 1,
#   'PINFISH': 1,
#   'GRAY SNAPPER': 1},
#  '2021-05-04': {'SPOTTED SEATROUT': 12,
#   'RED DRUM': 11,
#   'SOUTHERN KINGFISH': 10,
#   'NORTHERN PUFFER': 5,
#   'ATLANTIC CROAKER': 5,
#   'BLACK DRUM': 5,
#   'KING MACKEREL': 3,
#   'LANE SNAPPER': 2,
#   'CHANNEL CATFISH': 1,
#   'GRAY TRIGGERFISH': 1,
#   'DOLPHIN': 1,
#   'BLUEFISH': 1,
#   'PIGFISH': 1,
#   'SPANISH MACKEREL': 1},
#  '2021-05-05': {'SPANISH MACKEREL': 16,
#   'ATLANTIC CROAKER': 15,
#   'KING MACKEREL': 10,
#   'ROUND SCAD': 10,
#   'RED DRUM': 9,
#   'SHEEPSHEAD': 5,
#   'SAND SEATROUT': 5,
#   'DOLPHIN': 5,
#   'GREAT BARRACUDA': 4,
#   'SPOTTED SEATROUT': 4,
#   'BLUEFISH': 4,
#   'YELLOWTAIL SNAPPER': 3,
#   'BLACK DRUM': 3,
#   'GRAY SNAPPER': 3,
#   'STRIPED BASS': 2,
#   'GREATER AMBERJACK': 1,
#   'MUTTON SNAPPER': 1,
#   'BLACK GROUPER': 1,
#   'SOUTHERN FLOUNDER': 1,
#   'COBIA': 1},
#  '2021-05-06': {'SPOTTED SEATROUT': 32,
#   'SPANISH MACKEREL': 23,
#   'SCUP': 21,
#   'LITTLE TUNNY': 18,
#   'VERMILION SNAPPER': 17,
#   'KING MACKEREL': 13,
#   'RED DRUM': 10,
#   'ATLANTIC CROAKER': 10,
#   'TAUTOG': 8,
#   'BLUEFISH': 7,
#   'PINFISH': 6,
#   'ATLANTIC THREAD HERRING': 5,
#   'GRAY SNAPPER': 5,
#   'RED PORGY': 4,
#   'STRIPED BASS': 4,
#   'HOGFISH': 3,
#   'SUMMER FLOUNDER': 3,
#   'SOUTHERN KINGFISH': 3,
#   'GREATER AMBERJACK': 3,
#   'BLUE RUNNER': 2},
#  '2021-05-07': {'SPANISH MACKEREL': 98,
#   'HADDOCK': 85,
#   'ROUND SCAD': 64,
#   'VERMILION SNAPPER': 45,
#   'KING MACKEREL': 35,
#   'STRIPED BASS': 34,
#   'DOLPHIN': 28,
#   'BLUE RUNNER': 28,
#   'RED PORGY': 16,
#   'SOUTHERN KINGFISH': 15,
#   'BLUEFISH': 13,
#   'CUSK': 13,
#   'ATLANTIC SHARPNOSE SHARK': 12,
#   'SPOTTED SEATROUT': 11,
#   'LITTLE TUNNY': 11,
#   'RED DRUM': 10,
#   'LIONFISH': 9,
#   'GRAY SNAPPER': 8,
#   'FLORIDA POMPANO': 7,
#   'YELLOW JACK': 7},
#  '2021-05-08': {'HADDOCK': 144,
#   'WHITE GRUNT': 104,
#   'SPOTTED SEATROUT': 75,
#   'SOUTHERN KINGFISH': 64,
#   'SCUP': 61,
#   'ATLANTIC CROAKER': 51,
#   'VERMILION SNAPPER': 31,
#   'SOUTHERN FLOUNDER': 31,
#   'SPANISH MACKEREL': 27,
#   'BLUEFISH': 26,
#   'BLUE CATFISH': 23,
#   'SAND SEATROUT': 17,
#   'RED DRUM': 17,
#   'YELLOWFIN TUNA': 16,
#   'ACADIAN REDFISH': 15,
#   'PIGFISH': 14,
#   'PINFISH': 14,
#   'ROUND SCAD': 13,
#   'BLACK DRUM': 12,
#   'LITTLE TUNNY': 12},
#  '2021-05-09': {'HADDOCK': 58,
#   'TAUTOG': 41,
#   'SPANISH MACKEREL': 40,
#   'SCUP': 40,
#   'BLUEFISH': 32,
#   'KING MACKEREL': 27,
#   'YELLOWFIN TUNA': 20,
#   'STRIPED BASS': 19,
#   'DOLPHIN': 18,
#   'ACADIAN REDFISH': 14,
#   'BIGEYE TUNA': 14,
#   'SPOTTED SEATROUT': 12,
#   'BLUE CATFISH': 12,
#   'RED DRUM': 10,
#   'BLACKFIN TUNA': 10,
#   'SOUTHERN FLOUNDER': 6,
#   'STRIPED SEAROBIN': 6,
#   'ATLANTIC MACKEREL': 6,
#   'BLUELINE TILEFISH': 6,
#   'SUMMER FLOUNDER': 6},
#  '2021-05-10': {'VERMILION SNAPPER': 64,
#   'ROUND SCAD': 20,
#   'RED PORGY': 19,
#   'SOUTHERN KINGFISH': 18,
#   'PINFISH': 15,
#   'GREATER AMBERJACK': 9,
#   'GRAY SNAPPER': 8,
#   'BLUEFISH': 6,
#   'STRIPED BASS': 6,
#   'SPOT': 6,
#   'YELLOWTAIL SNAPPER': 5,
#   'RED DRUM': 4,
#   'GRAY TRIGGERFISH': 4,
#   'WEAKFISH': 4,
#   'LADYFISH': 3,
#   'ATLANTIC CROAKER': 2,
#   'CREVALLE JACK': 1,
#   'WHITEBONE PORGY': 1,
#   'BONNETHEAD': 1,
#   'LITTLE TUNNY': 1},
#  '2021-05-11': {'SOUTHERN KINGFISH': 43,
#   'WHITE GRUNT': 23,
#   'DOLPHIN': 14,
#   'LANE SNAPPER': 12,
#   'GRAY SNAPPER': 9,
#   'SPOT': 9,
#   'BLACKFIN TUNA': 8,
#   'PINFISH': 6,
#   'CHANNEL CATFISH': 5,
#   'ATLANTIC THREAD HERRING': 5,
#   'RED GROUPER': 4,
#   'WHITE CATFISH': 3,
#   'YELLOWFIN TUNA': 3,
#   'WEAKFISH': 2,
#   'BLACK SEA BASS': 2,
#   'BLUEFISH': 2,
#   'BLUE CATFISH': 2,
#   'SAND PERCH': 2,
#   'LITTLE TUNNY': 2,
#   'WAHOO': 1},
#  '2021-05-12': {'YELLOWTAIL SNAPPER': 12,
#   'SAND PERCH': 12,
#   'WHITE GRUNT': 12,
#   'TAUTOG': 10,
#   'SOUTHERN KINGFISH': 10,
#   'LITTLEHEAD PORGY': 8,
#   'LANE SNAPPER': 7,
#   'BLUEFISH': 6,
#   'SCUP': 6,
#   'ATLANTIC MACKEREL': 6,
#   'BLACKBELLY ROSEFISH': 4,
#   'STRIPED SEAROBIN': 3,
#   'YELLOW JACK': 3,
#   'DOLPHIN': 3,
#   'SPOT': 2,
#   'STRIPED BASS': 2,
#   'JOLTHEAD PORGY': 1,
#   'SOUTHERN HAKE': 1},
#  '2021-05-13': {'WHITE GRUNT': 38,
#   'SCUP': 21,
#   'ATLANTIC CROAKER': 17,
#   'SOUTHERN KINGFISH': 12,
#   'SPOTTED SEATROUT': 11,
#   'HADDOCK': 10,
#   'ATLANTIC MACKEREL': 10,
#   'SAND SEATROUT': 8,
#   'SPANISH MACKEREL': 7,
#   'WINTER FLOUNDER': 6,
#   'POLLOCK': 5,
#   'BLUE RUNNER': 4,
#   'STRIPED BASS': 3,
#   'STRIPED SEAROBIN': 3,
#   'TAUTOG': 3,
#   'GRAY SNAPPER': 2,
#   'RED DRUM': 2,
#   'WHITE HAKE': 2,
#   'ACADIAN REDFISH': 2,
#   'BLUEFISH': 2},
#  '2021-05-14': {'HADDOCK': 43,
#   'SPOTTED SEATROUT': 40,
#   'SUMMER FLOUNDER': 39,
#   'SPANISH MACKEREL': 26,
#   'GULF KINGFISH': 22,
#   'VERMILION SNAPPER': 20,
#   'TAUTOG': 20,
#   'RED DRUM': 19,
#   'SOUTHERN KINGFISH': 16,
#   'SCUP': 15,
#   'GRAY SNAPPER': 14,
#   'ATLANTIC BONITO': 11,
#   'ATLANTIC MACKEREL': 11,
#   'SAND SEATROUT': 10,
#   'TOMTATE': 10,
#   'FLORIDA POMPANO': 8,
#   'STRIPED MULLET': 7,
#   'LITTLE TUNNY': 7,
#   'BLUE RUNNER': 6,
#   'BLUEFISH': 6},
#  '2021-05-15': {'BLACK SEA BASS': 273,
#   'SCUP': 76,
#   'SPOTTED SEATROUT': 43,
#   'DOLPHIN': 30,
#   'SPANISH MACKEREL': 28,
#   'BLUE CATFISH': 28,
#   'PINFISH': 26,
#   'GRAY SNAPPER': 25,
#   'ATLANTIC MACKEREL': 24,
#   'SUMMER FLOUNDER': 21,
#   'TAUTOG': 19,
#   'HADDOCK': 19,
#   'SOUTHERN KINGFISH': 18,
#   'BLUEFISH': 18,
#   'BLACKFIN TUNA': 17,
#   'ATLANTIC CROAKER': 15,
#   'VERMILION SNAPPER': 11,
#   'BLUE RUNNER': 10,
#   'ATLANTIC COD': 8,
#   'GAFFTOPSAIL CATFISH': 8},
#  '2021-05-16': {'BLACK SEA BASS': 185,
#   'STRIPED BASS': 74,
#   'HADDOCK': 49,
#   'SPANISH MACKEREL': 41,
#   'SPOTTED SEATROUT': 40,
#   'WHITE GRUNT': 35,
#   'ATLANTIC MACKEREL': 28,
#   'VERMILION SNAPPER': 28,
#   'ATLANTIC THREAD HERRING': 25,
#   'SOUTHERN KINGFISH': 25,
#   'RED PORGY': 21,
#   'SUMMER FLOUNDER': 21,
#   'PINFISH': 19,
#   'RED DRUM': 18,
#   'SPOT': 17,
#   'BLUELINE TILEFISH': 17,
#   'BLUEFISH': 17,
#   'ATLANTIC CROAKER': 16,
#   'GRAY SNAPPER': 16,
#   'HARDHEAD CATFISH': 16},
#  '2021-05-17': {'BLACK SEA BASS': 59,
#   'SOUTHERN KINGFISH': 53,
#   'SPANISH MACKEREL': 21,
#   'DOLPHIN': 13,
#   'SPOTTED SEATROUT': 13,
#   'GRAY TRIGGERFISH': 10,
#   'HADDOCK': 10,
#   'SPOT': 9,
#   'STRIPED BASS': 6,
#   'BLUEFISH': 5,
#   'SUMMER FLOUNDER': 3,
#   'KING MACKEREL': 3,
#   'TAUTOG': 2,
#   'ATLANTIC CROAKER': 2,
#   'SOUTHERN FLOUNDER': 2,
#   'GULF KINGFISH': 2,
#   'SPOTTED HAKE': 1,
#   'CUNNER': 1,
#   'CUSK': 1,
#   'BLACK DRUM': 1},
#  '2021-05-18': {'HADDOCK': 102,
#   'SPANISH MACKEREL': 69,
#   'ACADIAN REDFISH': 46,
#   'DOLPHIN': 45,
#   'CUSK': 45,
#   'BLACK SEA BASS': 27,
#   'SPOTTED SEATROUT': 14,
#   'GRAY SNAPPER': 13,
#   'WHITE PERCH': 11,
#   'SOUTHERN KINGFISH': 9,
#   'BLUEFISH': 8,
#   'ATLANTIC CROAKER': 7,
#   'BLACK DRUM': 6,
#   'GRAY TRIGGERFISH': 6,
#   'SCUP': 6,
#   'GAFFTOPSAIL CATFISH': 5,
#   'VERMILION SNAPPER': 5,
#   'ATLANTIC THREAD HERRING': 5,
#   'PINFISH': 5,
#   'WHITE GRUNT': 5},
#  '2021-05-19': {'BLACK SEA BASS': 79,
#   'HADDOCK': 40,
#   'SPOTTED SEATROUT': 19,
#   'SCUP': 14,
#   'SPANISH MACKEREL': 13,
#   'DOLPHIN': 13,
#   'GRAY SNAPPER': 8,
#   'ATLANTIC CROAKER': 8,
#   'KING MACKEREL': 6,
#   'ACADIAN REDFISH': 4,
#   'SUMMER FLOUNDER': 4,
#   'PINFISH': 3,
#   'RED DRUM': 3,
#   'GREATER AMBERJACK': 3,
#   'TAUTOG': 3,
#   'GAG': 2,
#   'GREAT BARRACUDA': 2,
#   'STRIPED BASS': 2,
#   'RED HAKE': 1,
#   'CUSK': 1},
#  '2021-05-20': {'SPANISH MACKEREL': 47,
#   'GRAY TRIGGERFISH': 45,
#   'BLACK SEA BASS': 35,
#   'BLUEFISH': 33,
#   'DOLPHIN': 28,
#   'SUMMER FLOUNDER': 18,
#   'KING MACKEREL': 17,
#   'SCUP': 13,
#   'ATLANTIC MENHADEN': 12,
#   'VERMILION SNAPPER': 7,
#   'RED DRUM': 7,
#   'SOUTHERN KINGFISH': 6,
#   'BLACKFIN TUNA': 5,
#   'SHEEPSHEAD': 4,
#   'STRIPED BASS': 3,
#   'SKIPJACK TUNA': 2,
#   'GREATER AMBERJACK': 2,
#   'GAG': 2,
#   'NORTHERN SNAKEHEAD': 1,
#   'LITTLE TUNNY': 1},
#  '2021-05-21': {'BLACK SEA BASS': 105,
#   'HADDOCK': 95,
#   'BLUEFISH': 83,
#   'SCUP': 55,
#   'SOUTHERN KINGFISH': 37,
#   'SUMMER FLOUNDER': 33,
#   'STRIPED BASS': 31,
#   'SPOTTED SEATROUT': 21,
#   'RED DRUM': 20,
#   'SAND SEATROUT': 19,
#   'BLUE CATFISH': 18,
#   'ATLANTIC CROAKER': 18,
#   'ATLANTIC MACKEREL': 15,
#   'ACADIAN REDFISH': 14,
#   'SPOT': 12,
#   'SPANISH MACKEREL': 12,
#   'DOLPHIN': 11,
#   'YELLOWFIN TUNA': 11,
#   'HICKORY SHAD': 11,
#   'WHITE PERCH': 10},
#  '2021-05-22': {'HADDOCK': 191,
#   'BLACK SEA BASS': 133,
#   'SPANISH MACKEREL': 94,
#   'WHITE GRUNT': 50,
#   'BLUEFISH': 49,
#   'DOLPHIN': 44,
#   'YELLOWTAIL SNAPPER': 42,
#   'ATLANTIC MACKEREL': 33,
#   'GRAY SNAPPER': 31,
#   'SCUP': 31,
#   'SUMMER FLOUNDER': 19,
#   'WHITE PERCH': 17,
#   'BLACK DRUM': 16,
#   'ATLANTIC CROAKER': 14,
#   'RED PORGY': 12,
#   'WINTER FLOUNDER': 12,
#   'STRIPED BASS': 12,
#   'BLUELINE TILEFISH': 11,
#   'STRIPED SEAROBIN': 10,
#   'BLACKFIN TUNA': 10},
# ...
#   'RED DRUM': 31,
#   'STRIPED MULLET': 18,
#   'RED PORGY': 15,
#   'ATLANTIC CROAKER': 14,
#   'PIGFISH': 11,
#   'VERMILION SNAPPER': 10,
#   'SHEEPSHEAD': 9,
#   'DOLPHIN': 6,
#   'SPANISH MACKEREL': 6,
#   'WHITE GRUNT': 6,
#   'NORTHERN PUFFER': 5,
#   'PINFISH': 5,
#   'BLACK SEA BASS': 5,
#   'STRIPED BASS': 5,
#   'SCAMP': 4,
#   'GREATER AMBERJACK': 4,
#   'KING MACKEREL': 4,
#   'BLACK DRUM': 3},
#  '2021-11-13': {'TAUTOG': 123,
#   'BLACK SEA BASS': 103,
#   'GAG': 58,
#   'SPOTTED SEATROUT': 55,
#   'PINFISH': 47,
#   'SOUTHERN KINGFISH': 37,
#   'STRIPED BASS': 31,
#   'SHEEPSHEAD': 30,
#   'STRIPED MULLET': 27,
#   'NORTHERN PUFFER': 23,
#   'SILVER PERCH': 23,
#   'WHITE GRUNT': 22,
#   'VERMILION SNAPPER': 20,
#   'GRAY SNAPPER': 20,
#   'RED DRUM': 19,
#   'RED PORGY': 18,
#   'BLUEFISH': 16,
#   'SAND SEATROUT': 15,
#   'BLACK DRUM': 13,
#   'ATLANTIC MACKEREL': 12},
#  '2021-11-14': {'BLACK SEA BASS': 347,
#   'SPOTTED SEATROUT': 70,
#   'TAUTOG': 60,
#   'SOUTHERN KINGFISH': 37,
#   'GRAY SNAPPER': 33,
#   'SPANISH MACKEREL': 31,
#   'SHEEPSHEAD': 22,
#   'STRIPED BASS': 21,
#   'WHITE CRAPPIE': 21,
#   'GAG': 18,
#   'RED DRUM': 17,
#   'GRAY TRIGGERFISH': 16,
#   'PINFISH': 15,
#   'CREVALLE JACK': 12,
#   'YELLOWFIN TUNA': 12,
#   'DOLPHIN': 11,
#   'WHITE GRUNT': 11,
#   'ATLANTIC CROAKER': 10,
#   'SPOT': 9,
#   'BLACK DRUM': 7},
#  '2021-11-15': {'SPOTTED SEATROUT': 52,
#   'ATLANTIC THREAD HERRING': 15,
#   'PINFISH': 12,
#   'SOUTHERN KINGFISH': 9,
#   'WHITE GRUNT': 8,
#   'SPANISH MACKEREL': 7,
#   'RED DRUM': 6,
#   'SAND SEATROUT': 6,
#   'TAUTOG': 5,
#   'STRIPED BASS': 5,
#   'SPOT': 5,
#   'GAFFTOPSAIL CATFISH': 5,
#   'DOLPHIN': 4,
#   'GRAY SNAPPER': 3,
#   'LADYFISH': 3,
#   'ATLANTIC CROAKER': 3,
#   'BLACK SEA BASS': 2,
#   'GAG': 2,
#   'ATLANTIC COD': 1,
#   'MUTTON SNAPPER': 1},
#  '2021-11-16': {'SPOTTED SEATROUT': 21,
#   'SHEEPSHEAD': 10,
#   'NORTHERN PUFFER': 5,
#   'RED DRUM': 4,
#   'SAND SEATROUT': 4,
#   'SOUTHERN FLOUNDER': 1},
#  '2021-11-17': {'SPOTTED SEATROUT': 49,
#   'TAUTOG': 47,
#   'STRIPED MULLET': 15,
#   'GULF KINGFISH': 12,
#   'SAND SEATROUT': 9,
#   'RED DRUM': 8,
#   'NORTHERN PUFFER': 8,
#   'SOUTHERN KINGFISH': 7,
#   'SCUP': 7,
#   'BLACK SEA BASS': 5,
#   'LARGEMOUTH BASS': 5,
#   'BLUEFISH': 4,
#   'ATLANTIC CROAKER': 4,
#   'WHITE MULLET': 4,
#   'GRAY SNAPPER': 2,
#   'STRIPED BASS': 1,
#   'SPOT': 1,
#   'WHITE HAKE': 1,
#   'CUNNER': 1},
#  '2021-11-18': {'SPOTTED SEATROUT': 71,
#   'PIGFISH': 38,
#   'RED DRUM': 25,
#   'SOUTHERN KINGFISH': 23,
#   'GAG': 23,
#   'NORTHERN PUFFER': 18,
#   'TAUTOG': 14,
#   'ATLANTIC CROAKER': 10,
#   'STRIPED BASS': 10,
#   'SAND SEATROUT': 10,
#   'BLUEFISH': 7,
#   'SHEEPSHEAD': 7,
#   'SPOTTAIL PINFISH': 7,
#   'WHITE GRUNT': 6,
#   'PINFISH': 5,
#   'WHITE PERCH': 5,
#   'SPANISH MACKEREL': 5,
#   'SOUTHERN FLOUNDER': 3,
#   'BLACK SEA BASS': 3,
#   'SPINY DOGFISH': 2},
#  '2021-11-19': {'SPOTTED SEATROUT': 31,
#   'TAUTOG': 28,
#   'GAG': 25,
#   'VERMILION SNAPPER': 10,
#   'STRIPED MULLET': 10,
#   'YELLOWTAIL SNAPPER': 9,
#   'ATLANTIC CROAKER': 9,
#   'SHEEPSHEAD': 5,
#   'GULF KINGFISH': 5,
#   'STRIPED BASS': 5,
#   'GREATER AMBERJACK': 4,
#   'GAFFTOPSAIL CATFISH': 3,
#   'RED DRUM': 3,
#   'PINFISH': 3,
#   'BLACK DRUM': 3,
#   'BLACKFIN TUNA': 3,
#   'SOUTHERN KINGFISH': 2,
#   'NORTHERN PUFFER': 2,
#   'KING MACKEREL': 1,
#   'BLACK SEA BASS': 1},
#  '2021-11-20': {'BLACK SEA BASS': 513,
#   'TAUTOG': 165,
#   'SCUP': 133,
#   'STRIPED BASS': 48,
#   'SPOTTED SEATROUT': 46,
#   'RED DRUM': 27,
#   'WHITE PERCH': 19,
#   'BLUEFISH': 16,
#   'ATLANTIC MACKEREL': 15,
#   'ATLANTIC COD': 12,
#   'WHITE CRAPPIE': 11,
#   'SPOT': 11,
#   'SAND SEATROUT': 11,
#   'SOUTHERN KINGFISH': 9,
#   'GULF KINGFISH': 6,
#   'GRAY SNAPPER': 5,
#   'ATLANTIC CROAKER': 5,
#   'CUNNER': 4,
#   'SHEEPSHEAD': 2,
#   'CREVALLE JACK': 2},
#  '2021-11-21': {'TAUTOG': 157,
#   'BLACK SEA BASS': 79,
#   'STRIPED BASS': 56,
#   'NORTHERN PUFFER': 53,
#   'SPOTTED SEATROUT': 47,
#   'RED DRUM': 27,
#   'SHEEPSHEAD': 19,
#   'ATLANTIC MACKEREL': 15,
#   'BLUEFISH': 13,
#   'CUNNER': 11,
#   'SPOT': 10,
#   'ATLANTIC CROAKER': 10,
#   'SOUTHERN KINGFISH': 9,
#   'BROWN BULLHEAD': 8,
#   'SCUP': 8,
#   'FLORIDA POMPANO': 7,
#   'GULF KINGFISH': 6,
#   'KING MACKEREL': 6,
#   'WHITE PERCH': 5,
#   'PINFISH': 5},
#  '2021-11-22': {'SPOTTED SEATROUT': 16,
#   'RED DRUM': 13,
#   'SHEEPSHEAD': 13,
#   'STRIPED BASS': 12,
#   'GRAY SNAPPER': 11,
#   'ATLANTIC CROAKER': 10,
#   'STRIPED MULLET': 10,
#   'TAUTOG': 9,
#   'DOLPHIN': 9,
#   'LITTLE TUNNY': 8,
#   'YELLOWFIN TUNA': 7,
#   'GREAT BARRACUDA': 4,
#   'MUTTON SNAPPER': 1,
#   'SKIPJACK TUNA': 1},
#  '2021-11-23': {'SAND SEATROUT': 53,
#   'SOUTHERN KINGFISH': 38,
#   'TAUTOG': 15,
#   'ATLANTIC CROAKER': 15,
#   'SHEEPSHEAD': 3,
#   'SPOTTED SEATROUT': 1},
#  '2021-11-24': {'NORTHERN PUFFER': 23,
#   'TAUTOG': 20,
#   'STRIPED BASS': 12,
#   'BLUEFISH': 7,
#   'SHEEPSHEAD': 4,
#   'SPOTTED SEATROUT': 4,
#   'BLACK DRUM': 2},
#  '2021-11-25': {'STRIPED BASS': 2},
#  '2021-11-26': {'WHITE GRUNT': 87,
#   'GRAY SNAPPER': 44,
#   'SPANISH MACKEREL': 40,
#   'TAUTOG': 20,
#   'GAG': 14,
#   'YELLOWTAIL SNAPPER': 11,
#   'SAND PERCH': 10,
#   'BLUE RUNNER': 8,
#   'SHEEPSHEAD': 7,
#   'KING MACKEREL': 7,
#   'BLACK SEA BASS': 7,
#   'SAUCEREYE PORGY': 5,
#   'STRIPED MULLET': 5,
#   'GULF KINGFISH': 5,
#   'LITTLE TUNNY': 5,
#   'DOLPHIN': 5,
#   'FLORIDA POMPANO': 4,
#   'BLUEFISH': 3,
#   'BLACK CRAPPIE': 3,
#   'STRIPED BASS': 2},
#  '2021-11-27': {'SPANISH MACKEREL': 58,
#   'RED DRUM': 46,
#   'SPOTTED SEATROUT': 38,
#   'YELLOWTAIL SNAPPER': 26,
#   'ROUND SCAD': 20,
#   'RED SNAPPER': 13,
#   'LITTLE TUNNY': 11,
#   'BLACK DRUM': 9,
#   'KING MACKEREL': 8,
#   'BLUEFISH': 8,
#   'STRIPED MULLET': 7,
#   'CREVALLE JACK': 5,
#   'VERMILION SNAPPER': 5,
#   'MUTTON SNAPPER': 4,
#   'STRIPED BASS': 4,
#   'SHEEPSHEAD': 3,
#   'ATLANTIC CUTLASSFISH': 3,
#   'ATLANTIC CROAKER': 3,
#   'YELLOW JACK': 3,
#   'GRAY TRIGGERFISH': 2},
#  '2021-11-28': {'TAUTOG': 116,
#   'SPOTTED SEATROUT': 108,
#   'STRIPED BASS': 47,
#   'ATLANTIC CROAKER': 25,
#   'RED DRUM': 21,
#   'SOUTHERN KINGFISH': 19,
#   'BLACK SEA BASS': 18,
#   'LANE SNAPPER': 16,
#   'WHITE GRUNT': 13,
#   'ATLANTIC MENHADEN': 13,
#   'SHEEPSHEAD': 7,
#   'GAG': 6,
#   'BLUESTRIPED GRUNT': 6,
#   'PINFISH': 6,
#   'WEAKFISH': 5,
#   'GRAY SNAPPER': 5,
#   'GREAT BARRACUDA': 5,
#   'HICKORY SHAD': 5,
#   'BLUEFISH': 4,
#   'KING MACKEREL': 4},
#  '2021-11-29': {'SPOTTED SEATROUT': 44,
#   'RED DRUM': 5,
#   'SOUTHERN FLOUNDER': 2,
#   'SAND PERCH': 1},
#  '2021-11-30': {'STRIPED BASS': 30,
#   'SPOTTED SEATROUT': 30,
#   'WHITE GRUNT': 29,
#   'TAUTOG': 20,
#   'BLACK SEA BASS': 19,
#   'SHEEPSHEAD': 5,
#   'RED DRUM': 4,
#   'BLACK DRUM': 3,
#   'SAND SEATROUT': 3,
#   'ATLANTIC COD': 1,
#   'SILVER PERCH': 1,
#   'SOUTHERN KINGFISH': 1,
#   'GAG': 1},
#  '2021-12-01': {'SPOTTED SEATROUT': 28,
#   'STRIPED BASS': 17,
#   'WHITE MULLET': 15,
#   'ATLANTIC CROAKER': 10,
#   'STRIPED MULLET': 7,
#   'PINFISH': 5,
#   'WEAKFISH': 2,
#   'RED DRUM': 1},
#  '2021-12-02': {'SPOTTED SEATROUT': 51,
#   'GAG': 40,
#   'SAND SEATROUT': 21,
#   'WHITE GRUNT': 20,
#   'PINFISH': 15,
#   'SOUTHERN KINGFISH': 14,
#   'SHEEPSHEAD': 13,
#   'GRAY SNAPPER': 13,
#   'SPANISH MACKEREL': 12,
#   'GULF KINGFISH': 8,
#   'FLORIDA POMPANO': 7,
#   'RED DRUM': 6,
#   'CREVALLE JACK': 6,
#   'STRIPED MULLET': 6,
#   'STRIPED BASS': 5,
#   'BLACK DRUM': 5,
#   'ATLANTIC CROAKER': 5,
#   'DOLPHIN': 3,
#   'BLUE RUNNER': 2,
#   'BLUEFISH': 2},
#  '2021-12-03': {'SPOTTED SEATROUT': 36,
#   'VERMILION SNAPPER': 26,
#   'BLACK SEA BASS': 26,
#   'RED DRUM': 24,
#   'GULF KINGFISH': 22,
#   'SPANISH MACKEREL': 22,
#   'PINFISH': 20,
#   'YELLOWTAIL SNAPPER': 13,
#   'ROUND SCAD': 10,
#   'GAG': 8,
#   'SAND SEATROUT': 8,
#   'KING MACKEREL': 6,
#   'ATLANTIC CROAKER': 6,
#   'SOUTHERN KINGFISH': 6,
#   'BANDED RUDDERFISH': 5,
#   'WHITE GRUNT': 5,
#   'SHEEPSHEAD': 5,
#   'LITTLE TUNNY': 5,
#   'RED PORGY': 4,
#   'SOUTHERN FLOUNDER': 4},
#  '2021-12-04': {'SPOTTED SEATROUT': 76,
#   'TAUTOG': 76,
#   'SPANISH MACKEREL': 75,
#   'STRIPED BASS': 55,
#   'BLACK SEA BASS': 51,
#   'SHEEPSHEAD': 49,
#   'YELLOWFIN TUNA': 38,
#   'KING MACKEREL': 37,
#   'BLACK DRUM': 35,
#   'RED DRUM': 34,
#   'BLUEFISH': 31,
#   'GRAY SNAPPER': 23,
#   'SAND SEATROUT': 17,
#   'WHITE GRUNT': 17,
#   'SOUTHERN KINGFISH': 15,
#   'NORTHERN PUFFER': 14,
#   'LANE SNAPPER': 14,
#   'BLUE CATFISH': 12,
#   'BLUE RUNNER': 10,
#   'DOLPHIN': 10},
#  '2021-12-05': {'STRIPED BASS': 44,
#   'SPANISH MACKEREL': 28,
#   'SPOTTED SEATROUT': 21,
#   'TAUTOG': 20,
#   'SOUTHERN KINGFISH': 12,
#   'NORTHERN PUFFER': 11,
#   'BLACK CRAPPIE': 8,
#   'KING MACKEREL': 7,
#   'BLUEFISH': 6,
#   'LANE SNAPPER': 6,
#   'GRAY SNAPPER': 5,
#   'WHITE GRUNT': 5,
#   'BLACKBELLY ROSEFISH': 5,
#   'BLACKFIN TUNA': 4,
#   'GAG': 3,
#   'TOMTATE': 2,
#   'BLACK DRUM': 2,
#   'BANDED RUDDERFISH': 2,
#   'PINFISH': 2,
#   'YELLOW PERCH': 2},
#  '2021-12-06': {'NORTHERN PUFFER': 4,
#   'SPOTTED SEATROUT': 2,
#   'GULF KINGFISH': 1,
#   'ATLANTIC CROAKER': 1,
#   'SPANISH MACKEREL': 1},
#  '2021-12-07': {'STRIPED BASS': 20,
#   'SPOTTED SEATROUT': 15,
#   'TAUTOG': 8,
#   'PIGFISH': 2,
#   'BLUEFISH': 2,
#   'BLACK DRUM': 2,
#   'RED DRUM': 2,
#   'SWORDFISH': 1},
#  '2021-12-08': {'SPANISH MACKEREL': 30,
#   'TAUTOG': 26,
#   'GRAY SNAPPER': 20,
#   'YELLOWFIN MENHADEN': 19,
#   'BLUEFISH': 16,
#   'SPOTTED SEATROUT': 10,
#   'SAND SEATROUT': 9,
#   'GAG': 7,
#   'PIGFISH': 7,
#   'BLACK SEA BASS': 5,
#   'ATLANTIC HERRING': 5,
#   'PINFISH': 3,
#   'COMMON SNOOK': 2,
#   'SCUP': 2,
#   'WHITE GRUNT': 2,
#   'BLUE RUNNER': 1,
#   'HICKORY SHAD': 1},
#  '2021-12-09': {'GULF KINGFISH': 15,
#   'WHITE GRUNT': 13,
#   'KING MACKEREL': 8,
#   'GRAY SNAPPER': 6,
#   'SPOTTED SEATROUT': 6,
#   'SHEEPSHEAD': 4,
#   'BLACK DRUM': 4,
#   'COBIA': 1,
#   'LADYFISH': 1,
#   'FLORIDA POMPANO': 1},
#  '2021-12-10': {'SOUTHERN KINGFISH': 33,
#   'SPOTTED SEATROUT': 23,
#   'GRAY SNAPPER': 21,
#   'STRIPED BASS': 17,
#   'WHITE GRUNT': 15,
#   'BLACK SEA BASS': 12,
#   'YELLOWFIN TUNA': 9,
#   'RED DRUM': 9,
#   'TAUTOG': 8,
#   'GAG': 8,
#   'BLACKFIN TUNA': 8,
#   'LADYFISH': 6,
#   'HOGFISH': 6,
#   'SHEEPSHEAD': 6,
#   'VERMILION SNAPPER': 6,
#   'PINFISH': 5,
#   'KING MACKEREL': 4,
#   'YELLOW CHUB': 4,
#   'BLUEFISH': 3,
#   'FLORIDA POMPANO': 3},
#  '2021-12-11': {'WHITE GRUNT': 69,
#   'KING MACKEREL': 62,
#   'SPOTTED SEATROUT': 31,
#   'GAG': 27,
#   'SHEEPSHEAD': 15,
#   'LITTLEHEAD PORGY': 15,
#   'GRAY SNAPPER': 11,
#   'LANE SNAPPER': 6,
#   'HOGFISH': 5,
#   'SOUTHERN KINGFISH': 5,
#   'RED DRUM': 4,
#   'TRIPLETAIL': 4,
#   'STRIPED BASS': 3,
#   'LITTLE TUNNY': 2,
#   'GRAYSBY': 2,
#   'BLACK DRUM': 2,
#   'RED SNAPPER': 2,
#   'SPANISH MACKEREL': 2,
#   'TAUTOG': 1,
#   'ATLANTIC CROAKER': 1},
#  '2021-12-12': {'SHEEPSHEAD': 24,
#   'PINFISH': 23,
#   'SPOTTED SEATROUT': 23,
#   'CREVALLE JACK': 23,
#   'STRIPED BASS': 23,
#   'SPANISH MACKEREL': 19,
#   'BLUEFISH': 17,
#   'VERMILION SNAPPER': 16,
#   'GRAY SNAPPER': 13,
#   'WHITE PERCH': 12,
#   'RED DRUM': 11,
#   'COMMON SNOOK': 6,
#   'WHITE GRUNT': 6,
#   'BLACK SEA BASS': 5,
#   'ATLANTIC CROAKER': 5,
#   'SAND SEATROUT': 5,
#   'STRIPED MULLET': 4,
#   'ATLANTIC THREAD HERRING': 4,
#   'HARDHEAD CATFISH': 3,
#   'TAUTOG': 2},
#  '2021-12-13': {'RED DRUM': 8,
#   'GULF KINGFISH': 3,
#   'SOUTHERN FLOUNDER': 3,
#   'BLUEFISH': 2,
#   'SPOT': 2,
#   'SHEEPSHEAD': 2,
#   'STRIPED BASS': 1,
#   'WHITEBONE PORGY': 1,
#   'TOMTATE': 1},
#  '2021-12-14': {'BLACK SEA BASS': 28,
#   'SPOTTED SEATROUT': 12,
#   'TAUTOG': 11,
#   'SAND SEATROUT': 10,
#   'STRIPED BASS': 5,
#   'SHEEPSHEAD': 5,
#   'CUNNER': 4,
#   'ATLANTIC CROAKER': 3,
#   'ATLANTIC COD': 2,
#   'SPANISH MACKEREL': 2,
#   'LADYFISH': 2,
#   'PINFISH': 2,
#   'RED DRUM': 1,
#   'BLUEFISH': 1},
#  '2021-12-15': {'BLACK SEA BASS': 296,
#   'SPOTTED SEATROUT': 31,
#   'SPANISH MACKEREL': 13,
#   'PINFISH': 10,
#   'SAND PERCH': 10,
#   'WHITE GRUNT': 8,
#   'RED DRUM': 6,
#   'GAG': 5,
#   'STRIPED BASS': 4,
#   'BLUEFISH': 4,
#   'CLEARNOSE SKATE': 1,
#   'SUMMER FLOUNDER': 1,
#   'FLORIDA POMPANO': 1,
#   'GRAY SNAPPER': 1},
#  '2021-12-16': {'SPINY DOGFISH': 12,
#   'SHEEPSHEAD': 9,
#   'WHITE GRUNT': 6,
#   'LITTLE TUNNY': 5,
#   'BLACK SEA BASS': 5,
#   'GRAYSBY': 5,
#   'VERMILION SNAPPER': 5,
#   'NORTHERN PUFFER': 4,
#   'SPOTTED SEATROUT': 4,
#   'GRAY SNAPPER': 3,
#   'RED PORGY': 2,
#   'RED DRUM': 1,
#   'COBIA': 1,
#   'GREATER AMBERJACK': 1,
#   'KNOBBED PORGY': 1},
#  '2021-12-17': {'SHEEPSHEAD': 33,
#   'GULF KINGFISH': 29,
#   'GAG': 27,
#   'SOUTHERN KINGFISH': 26,
#   'RED DRUM': 24,
#   'BLUE RUNNER': 22,
#   'SPOTTED SEATROUT': 22,
#   'STRIPED BASS': 21,
#   'TAUTOG': 16,
#   'LANE SNAPPER': 10,
#   'GRAY SNAPPER': 10,
#   'WHITE GRUNT': 7,
#   'LADYFISH': 6,
#   'INSHORE LIZARDFISH': 5,
#   'MUTTON SNAPPER': 5,
#   'SPANISH MACKEREL': 5,
#   'LOOKDOWN': 4,
#   'PINFISH': 3,
#   'SPOTTAIL PINFISH': 3,
#   'YELLOWTAIL SNAPPER': 3},
#  '2021-12-18': {'SPOTTED SEATROUT': 29,
#   'VERMILION SNAPPER': 24,
#   'SHEEPSHEAD': 21,
#   'ROUND SCAD': 20,
#   'TAUTOG': 11,
#   'BLACK SEA BASS': 8,
#   'STRIPED BASS': 7,
#   'WHITE GRUNT': 5,
#   'PINFISH': 5,
#   'GREATER AMBERJACK': 4,
#   'RED DRUM': 2,
#   'LITTLE TUNNY': 2,
#   'JOLTHEAD PORGY': 2,
#   'CUNNER': 2,
#   'SNOWY GROUPER': 1,
#   'KING MACKEREL': 1,
#   'LADYFISH': 1,
#   'ATLANTIC CROAKER': 1,
#   'ALMACO JACK': 1,
#   'SUMMER FLOUNDER': 1},
#  '2021-12-19': {'WHITE GRUNT': 68,
#   'GRAY SNAPPER': 46,
#   'KING MACKEREL': 43,
#   'YELLOWTAIL SNAPPER': 27,
#   'LITTLE TUNNY': 13,
#   'SPANISH MACKEREL': 11,
#   'BLUE RUNNER': 10,
#   'GAG': 9,
#   'YELLOW PERCH': 8,
#   'PINFISH': 8,
#   'SOUTHERN KINGFISH': 6,
#   'SPOTTED SEATROUT': 6,
#   'JOLTHEAD PORGY': 6,
#   'GULF KINGFISH': 5,
#   'HARDHEAD CATFISH': 5,
#   'SAND SEATROUT': 5,
#   'SHEEPSHEAD': 5,
#   'GREAT BARRACUDA': 4,
#   'LITTLEHEAD PORGY': 4,
#   'LADYFISH': 4},
#  '2021-12-20': {'BLACK SEA BASS': 55,
#   'GRAY SNAPPER': 9,
#   'STRIPED BASS': 4,
#   'SCUP': 3,
#   'SHEEPSHEAD': 3,
#   'BLUEFISH': 2,
#   'PIGFISH': 2,
#   'ATLANTIC HERRING': 1,
#   'RED DRUM': 1,
#   'GAG': 1},
#  '2021-12-21': {'PINFISH': 5,
#   'STRIPED BASS': 2,
#   'GULF KINGFISH': 2,
#   'BLUE CATFISH': 1},
#  '2021-12-22': {},
#  '2021-12-23': {'SPOTTED SEATROUT': 8,
#   'ATLANTIC CROAKER': 5,
#   'STRIPED MULLET': 5,
#   'GRAY SNAPPER': 5,
#   'LITTLE TUNNY': 4,
#   'YELLOW JACK': 4,
#   'SAND SEATROUT': 3,
#   'SHEEPSHEAD': 3,
#   'GREAT BARRACUDA': 2,
#   'SPANISH MACKEREL': 2,
#   'DOLPHIN': 1,
#   'LANE SNAPPER': 1,
#   'KING MACKEREL': 1},
#  '2021-12-24': {'LANE SNAPPER': 18,
#   'TAUTOG': 17,
#   'PIGFISH': 9,
#   'BLUEFISH': 8,
#   'GRAY SNAPPER': 8,
#   'SPANISH MACKEREL': 5,
#   'SILVER PERCH': 5,
#   'RED DRUM': 3,
#   'STRIPED BASS': 2,
#   'SHEEPSHEAD': 2,
#   'CREVALLE JACK': 2,
#   'WHITEBONE PORGY': 1,
#   'MUTTON SNAPPER': 1},
#  '2021-12-25': {},
#  '2021-12-26': {'SPOTTED SEATROUT': 51,
#   'GAG': 40,
#   'SHEEPSHEAD': 36,
#   'NORTHERN PUFFER': 31,
#   'GRAY SNAPPER': 31,
#   'BLACK CRAPPIE': 17,
#   'RED DRUM': 15,
#   'WHITE GRUNT': 14,
#   'SPANISH MACKEREL': 11,
#   'VERMILION SNAPPER': 10,
#   'SOUTHERN KINGFISH': 10,
#   'LADYFISH': 9,
#   'GULF KINGFISH': 8,
#   'STRIPED BASS': 8,
#   'JOLTHEAD PORGY': 8,
#   'CREVALLE JACK': 6,
#   'SAND SEATROUT': 6,
#   'LANE SNAPPER': 6,
#   'SCAMP': 6,
#   'YELLOW PERCH': 6},
#  '2021-12-27': {'SPOTTED SEATROUT': 31,
#   'BLACK SEA BASS': 16,
#   'BLACK DRUM': 7,
#   'PIGFISH': 7,
#   'STRIPED BASS': 2},
#  '2021-12-28': {'BLACK SEA BASS': 230,
#   'SCUP': 20,
#   'BLUEFISH': 20,
#   'BLACK CRAPPIE': 10,
#   'SOUTHERN KINGFISH': 8,
#   'SPOTTED SEATROUT': 8,
#   'PIGFISH': 8,
#   'SPANISH SARDINE': 8,
#   'GULF KINGFISH': 7,
#   'ATLANTIC CROAKER': 7,
#   'WEAKFISH': 6,
#   'YELLOW PERCH': 5,
#   'TAUTOG': 5,
#   'LANE SNAPPER': 4,
#   'GRAY SNAPPER': 4,
#   'PINFISH': 3,
#   'NORTHERN PUFFER': 2,
#   'BLACK DRUM': 2,
#   'SHEEPSHEAD': 2,
#   'SPOTTAIL PINFISH': 1},
#  '2021-12-29': {'WHITE GRUNT': 47,
#   'GRAY SNAPPER': 39,
#   'LANE SNAPPER': 33,
#   'ATLANTIC HERRING': 22,
#   'SPANISH MACKEREL': 15,
#   'SHEEPSHEAD': 8,
#   'SPOTTED SEATROUT': 7,
#   'LITTLEHEAD PORGY': 7,
#   'YELLOWTAIL SNAPPER': 6,
#   'VERMILION SNAPPER': 5,
#   'RED PORGY': 4,
#   'ALMACO JACK': 3,
#   'HOGFISH': 3,
#   'GAG': 2,
#   'GRAYSBY': 2,
#   'PINFISH': 1,
#   'BONNETHEAD': 1,
#   'KNOBBED PORGY': 1,
#   'CERO': 1},
#  '2021-12-30': {'SPOTTED SEATROUT': 28,
#   'TAUTOG': 18,
#   'RED DRUM': 12,
#   'NORTHERN PUFFER': 10,
#   'BLACK SEA BASS': 5,
#   'PIGFISH': 1,
#   'PINFISH': 1},
#  '2021-12-31': {'STRIPED BASS': 50,
#   'BLACK SEA BASS': 45,
#   'YELLOWTAIL SNAPPER': 33,
#   'WHITE GRUNT': 31,
#   'VERMILION SNAPPER': 27,
#   'GRAY SNAPPER': 24,
#   'SAND SEATROUT': 23,
#   'BLACKFIN TUNA': 19,
#   'SPOTTED SEATROUT': 19,
#   'NORTHERN PUFFER': 12,
#   'TAUTOG': 11,
#   'ATLANTIC THREAD HERRING': 10,
#   'SHEEPSHEAD': 9,
#   'CERO': 5,
#   'RED PORGY': 5,
#   'LITTLEHEAD PORGY': 5,
#   'SAND PERCH': 5,
#   'GREAT BARRACUDA': 5,
#   'MUTTON SNAPPER': 4,
#   'JOLTHEAD PORGY': 4}}

# %%
list_fish = list(df['common'].dropna().unique())
fish_stat = {} #这个字典key是鱼的名字，值是鱼的最大长度，最小长度，平均长度，最大重量，最小重量，平均重量


d1 = df[['common','LNGTH','WGT']].dropna()
k = df1.groupby('common').agg({'LNGTH':['max','min','mean'],'WGT':['max','min','mean']})
k.columns = ['max_lngth','min_lngth','mean_lngth','max_wgt','min_wgt','mean_wgt']
# for i in ff['common']:
for i in range(len(k)):
    temp_dict = {k.index[i]:dict(k.iloc[i])}
    fish_stat.update(temp_dict)
fish_stat
# Out:
# {'ACADIAN REDFISH': {'max_lngth': 437.0,
#   'min_lngth': 106.0,
#   'mean_lngth': 265.32859281437123,
#   'max_wgt': 1.24,
#   'min_wgt': 0.03,
#   'mean_wgt': 0.3293937125748503},
#  'AFRICAN POMPANO': {'max_lngth': 1000.0,
#   'min_lngth': 584.0,
#   'mean_lngth': 801.2592592592592,
#   'max_wgt': 13.22,
#   'min_wgt': 3.01,
#   'mean_wgt': 7.695555555555556},
#  'ALBACORE': {'max_lngth': 968.0,
#   'min_lngth': 790.0,
#   'mean_lngth': 871.6923076923077,
#   'max_wgt': 16.18,
#   'min_wgt': 10.26,
#   'mean_wgt': 12.918461538461539},
#  'ALMACO JACK': {'max_lngth': 912.0,
#   'min_lngth': 225.0,
#   'mean_lngth': 423.0036832412523,
#   'max_wgt': 11.12,
#   'min_wgt': 0.22,
#   'mean_wgt': 1.7378268876611418},
#  'AMERICAN EEL': {'max_lngth': 984.0,
#   'min_lngth': 719.0,
#   'mean_lngth': 864.5555555555555,
#   'max_wgt': 2.29,
#   'min_wgt': 0.85,
#   'mean_wgt': 1.5422222222222222},
#  'ATLANTIC BONITO': {'max_lngth': 644.0,
#   'min_lngth': 244.0,
#   'mean_lngth': 505.72972972972974,
#   'max_wgt': 4.1,
#   'min_wgt': 0.2,
#   'mean_wgt': 2.12036036036036},
#  'ATLANTIC BUMPER': {'max_lngth': 178.0,
#   'min_lngth': 178.0,
#   'mean_lngth': 178.0,
#   'max_wgt': 0.1,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.1},
#  'ATLANTIC COD': {'max_lngth': 905.0,
#   'min_lngth': 328.0,
#   'mean_lngth': 583.0253807106599,
#   'max_wgt': 7.87,
#   'min_wgt': 0.37,
#   'mean_wgt': 2.265},
#  'ATLANTIC CROAKER': {'max_lngth': 443.0,
#   'min_lngth': 109.0,
#   'mean_lngth': 224.8337868212469,
#   'max_wgt': 1.04,
#   'min_wgt': 0.02,
#   'mean_wgt': 0.15232698450254348},
#  'ATLANTIC CUTLASSFISH': {'max_lngth': 1886.0,
#   'min_lngth': 455.0,
#   'mean_lngth': 960.9480286738351,
#   'max_wgt': 2.1,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.7741935483870968},
#  'ATLANTIC HERRING': {'max_lngth': 314.0,
#   'min_lngth': 153.0,
#   'mean_lngth': 249.99411764705883,
#   'max_wgt': 0.32,
#   'min_wgt': 0.04,
#   'mean_wgt': 0.16958823529411765},
#  'ATLANTIC MACKEREL': {'max_lngth': 461.0,
#   'min_lngth': 168.0,
#   'mean_lngth': 245.85193160227993,
#   'max_wgt': 1.09,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.18581127295756808},
#  'ATLANTIC MENHADEN': {'max_lngth': 324.0,
#   'min_lngth': 68.0,
#   'mean_lngth': 252.72584033613447,
#   'max_wgt': 0.55,
#   'min_wgt': 0.03,
#   'mean_wgt': 0.28789915966386553},
#  'ATLANTIC MOONFISH': {'max_lngth': 286.0,
#   'min_lngth': 280.0,
#   'mean_lngth': 283.6666666666667,
#   'max_wgt': 0.5,
#   'min_wgt': 0.45,
#   'mean_wgt': 0.4666666666666666},
#  'ATLANTIC NEEDLEFISH': {'max_lngth': 1042.0,
#   'min_lngth': 1042.0,
#   'mean_lngth': 1042.0,
#   'max_wgt': 1.6,
#   'min_wgt': 1.6,
#   'mean_wgt': 1.6},
#  'ATLANTIC SHARPNOSE SHARK': {'max_lngth': 1097.0,
#   'min_lngth': 293.0,
#   'mean_lngth': 746.3030303030303,
#   'max_wgt': 9.86,
#   'min_wgt': 0.2,
#   'mean_wgt': 3.275378787878788},
#  'ATLANTIC SILVERSIDE': {'max_lngth': 129.0,
#   'min_lngth': 78.0,
#   'mean_lngth': 97.14285714285714,
#   'max_wgt': nan,
#   'min_wgt': nan,
#   'mean_wgt': nan},
#  'ATLANTIC SPADEFISH': {'max_lngth': 566.0,
#   'min_lngth': 125.0,
#   'mean_lngth': 268.11009174311926,
#   'max_wgt': 4.36,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.9169266055045873},
#  'ATLANTIC STINGRAY': {'max_lngth': 780.0,
#   'min_lngth': 236.0,
#   'mean_lngth': 401.14285714285717,
#   'max_wgt': 2.72,
#   'min_wgt': 0.5,
#   'mean_wgt': 1.4271428571428573},
#  'ATLANTIC THREAD HERRING': {'max_lngth': 274.0,
#   'min_lngth': 110.0,
#   'mean_lngth': 224.95503597122303,
#   'max_wgt': 0.4,
#   'min_wgt': 0.01,
#   'mean_wgt': 0.2528776978417266},
#  'BALLYHOO': {'max_lngth': 335.0,
#   'min_lngth': 324.0,
#   'mean_lngth': 329.5,
#   'max_wgt': 0.07,
#   'min_wgt': 0.06,
#   'mean_wgt': 0.065},
#  'BANDED RUDDERFISH': {'max_lngth': 514.0,
#   'min_lngth': 207.0,
#   'mean_lngth': 421.6296296296296,
#   'max_wgt': 2.2,
#   'min_wgt': 0.19,
#   'mean_wgt': 1.350833333333333},
#  'BANK SEA BASS': {'max_lngth': 304.0,
#   'min_lngth': 194.0,
#   'mean_lngth': 260.2,
#   'max_wgt': 0.3,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.1935},
#  'BAR JACK': {'max_lngth': 408.0,
#   'min_lngth': 142.0,
#   'mean_lngth': 275.0,
#   'max_wgt': 1.4,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.725},
#  'BARRELFISH': {'max_lngth': 474.0,
#   'min_lngth': 474.0,
#   'mean_lngth': 474.0,
#   'max_wgt': 2.36,
#   'min_wgt': 2.36,
#   'mean_wgt': 2.36},
#  'BEARDED BROTULA': {'max_lngth': 789.0,
#   'min_lngth': 789.0,
#   'mean_lngth': 789.0,
#   'max_wgt': 5.1,
#   'min_wgt': 5.1,
#   'mean_wgt': 5.1},
#  'BERMUDA CHUB': {'max_lngth': 445.0,
#   'min_lngth': 218.0,
#   'mean_lngth': 324.4634146341463,
#   'max_wgt': 1.98,
#   'min_wgt': 0.27,
#   'mean_wgt': 0.8719512195121951},
#  'BIGEYE': {'max_lngth': 358.0,
#   'min_lngth': 263.0,
#   'mean_lngth': 305.2,
#   'max_wgt': 0.76,
#   'min_wgt': 0.32,
#   'mean_wgt': 0.491},
#  'BIGEYE TUNA': {'max_lngth': 2064.0,
#   'min_lngth': 537.0,
#   'mean_lngth': 1364.64,
#   'max_wgt': 108.0,
#   'min_wgt': 3.5,
#   'mean_wgt': 47.2443},
#  'BIGSCALE POMFRET': {'max_lngth': 627.0,
#   'min_lngth': 627.0,
#   'mean_lngth': 627.0,
#   'max_wgt': 6.98,
#   'min_wgt': 6.98,
#   'mean_wgt': 6.98},
#  'BLACK CRAPPIE': {'max_lngth': 305.0,
#   'min_lngth': 220.0,
#   'mean_lngth': 262.15942028985506,
#   'max_wgt': 0.6,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.3536231884057971},
#  'BLACK DRUM': {'max_lngth': 1227.0,
#   'min_lngth': 223.0,
#   'mean_lngth': 464.2974537037037,
#   'max_wgt': 30.27,
#   'min_wgt': 0.17,
#   'mean_wgt': 2.0447222222222226},
#  'BLACK GROUPER': {'max_lngth': 855.0,
#   'min_lngth': 575.0,
#   'mean_lngth': 688.28,
#   'max_wgt': 10.14,
#   'min_wgt': 3.04,
#   'mean_wgt': 5.4456},
#  'BLACK JACK': {'max_lngth': 611.0,
#   'min_lngth': 611.0,
#   'mean_lngth': 611.0,
#   'max_wgt': 4.4,
#   'min_wgt': 4.4,
#   'mean_wgt': 4.4},
#  'BLACK MARGATE': {'max_lngth': 530.0,
#   'min_lngth': 180.0,
#   'mean_lngth': 290.10714285714283,
#   'max_wgt': 3.6,
#   'min_wgt': 0.14,
#   'mean_wgt': 0.7342857142857142},
#  'BLACK SEA BASS': {'max_lngth': 620.0,
#   'min_lngth': 128.0,
#   'mean_lngth': 396.6007771371271,
#   'max_wgt': 2.9,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.7980452494359489},
#  'BLACKBELLY ROSEFISH': {'max_lngth': 419.0,
#   'min_lngth': 234.0,
#   'mean_lngth': 328.9756097560976,
#   'max_wgt': 1.52,
#   'min_wgt': 0.22,
#   'mean_wgt': 0.6561788617886178},
#  'BLACKFIN SNAPPER': {'max_lngth': 269.0,
#   'min_lngth': 225.0,
#   'mean_lngth': 250.16666666666666,
#   'max_wgt': 0.4,
#   'min_wgt': 0.18,
#   'mean_wgt': 0.2833333333333333},
#  'BLACKFIN TUNA': {'max_lngth': 881.0,
#   'min_lngth': 288.0,
#   'mean_lngth': 531.8803945745992,
#   'max_wgt': 13.75,
#   'min_wgt': 0.5,
#   'mean_wgt': 3.620813810110974},
#  'BLACKNOSE SHARK': {'max_lngth': 1052.0,
#   'min_lngth': 828.0,
#   'mean_lngth': 941.7307692307693,
#   'max_wgt': 14.3,
#   'min_wgt': 5.42,
#   'mean_wgt': 9.083076923076923},
#  'BLACKTIP SHARK': {'max_lngth': 1700.0,
#   'min_lngth': 619.0,
#   'mean_lngth': 998.3833333333333,
#   'max_wgt': 47.0,
#   'min_wgt': 2.04,
#   'mean_wgt': 13.392166666666666},
#  'BLACKWING SEAROBIN': {'max_lngth': 326.0,
#   'min_lngth': 326.0,
#   'mean_lngth': 326.0,
#   'max_wgt': 0.4,
#   'min_wgt': 0.4,
#   'mean_wgt': 0.4},
#  'BLUE ANGELFISH': {'max_lngth': 355.0,
#   'min_lngth': 307.0,
#   'mean_lngth': 331.0,
#   'max_wgt': 1.0,
#   'min_wgt': 0.75,
#   'mean_wgt': 0.875},
#  'BLUE CATFISH': {'max_lngth': 780.0,
#   'min_lngth': 221.0,
#   'mean_lngth': 487.96743295019155,
#   'max_wgt': 9.7,
#   'min_wgt': 0.15,
#   'mean_wgt': 2.0968199233716476},
#  'BLUE MARLIN': {'max_lngth': 2623.0,
#   'min_lngth': 2623.0,
#   'mean_lngth': 2623.0,
#   'max_wgt': 176.0,
#   'min_wgt': 176.0,
#   'mean_wgt': 176.0},
#  'BLUE PARROTFISH': {'max_lngth': 398.0,
#   'min_lngth': 398.0,
#   'mean_lngth': 398.0,
#   'max_wgt': 1.46,
#   'min_wgt': 1.46,
#   'mean_wgt': 1.46},
#  'BLUE RUNNER': {'max_lngth': 540.0,
#   'min_lngth': 126.0,
#   'mean_lngth': 275.21205098493624,
#   'max_wgt': 1.68,
#   'min_wgt': 0.06,
#   'mean_wgt': 0.4279837775202781},
#  'BLUEFIN TUNA': {'max_lngth': 1802.0,
#   'min_lngth': 718.0,
#   'mean_lngth': 913.8538011695906,
#   'max_wgt': 87.49,
#   'min_wgt': 7.0,
#   'mean_wgt': 15.565146198830409},
#  'BLUEFISH': {'max_lngth': 814.0,
#   'min_lngth': 113.0,
#   'mean_lngth': 424.287831699737,
#   'max_wgt': 6.9,
#   'min_wgt': 0.02,
#   'mean_wgt': 1.4222161128376762},
#  'BLUEGILL': {'max_lngth': 228.0,
#   'min_lngth': 178.0,
#   'mean_lngth': 189.0,
#   'max_wgt': 0.3,
#   'min_wgt': 0.14,
#   'mean_wgt': 0.17333333333333334},
#  'BLUELINE TILEFISH': {'max_lngth': 898.0,
#   'min_lngth': 284.0,
#   'mean_lngth': 588.1580952380953,
#   'max_wgt': 6.7,
#   'min_wgt': 0.28,
#   'mean_wgt': 2.8291999999999997},
#  'BLUESTRIPED GRUNT': {'max_lngth': 268.0,
#   'min_lngth': 204.0,
#   'mean_lngth': 233.86363636363637,
#   'max_wgt': 0.38,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.24000000000000002},
#  'BONNETHEAD': {'max_lngth': 1000.0,
#   'min_lngth': 565.0,
#   'mean_lngth': 780.5833333333334,
#   'max_wgt': 6.61,
#   'min_wgt': 1.5,
#   'mean_wgt': 4.0104999999999995},
#  'BROWN BULLHEAD': {'max_lngth': 422.0,
#   'min_lngth': 270.0,
#   'mean_lngth': 349.09090909090907,
#   'max_wgt': 1.25,
#   'min_wgt': 0.3,
#   'mean_wgt': 0.7727272727272727},
#  'BULL SHARK': {'max_lngth': 1163.0,
#   'min_lngth': 1163.0,
#   'mean_lngth': 1163.0,
#   'max_wgt': 43.16,
#   'min_wgt': 43.16,
#   'mean_wgt': 43.16},
#  'CAESAR GRUNT': {'max_lngth': 222.0,
#   'min_lngth': 222.0,
#   'mean_lngth': 222.0,
#   'max_wgt': 0.2,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.2},
#  'CAROLINA HAKE': {'max_lngth': 396.0,
#   'min_lngth': 396.0,
#   'mean_lngth': 396.0,
#   'max_wgt': 0.8,
#   'min_wgt': 0.8,
#   'mean_wgt': 0.8},
#  'CERO': {'max_lngth': 668.0,
#   'min_lngth': 333.0,
#   'mean_lngth': 528.696551724138,
#   'max_wgt': 3.02,
#   'min_wgt': 0.32,
#   'mean_wgt': 1.5033793103448276},
#  'CHANNEL CATFISH': {'max_lngth': 653.0,
#   'min_lngth': 204.0,
#   'mean_lngth': 479.15972222222223,
#   'max_wgt': 5.2,
#   'min_wgt': 0.1,
#   'mean_wgt': 1.7625000000000002},
#  'CHUB MACKEREL': {'max_lngth': 485.0,
#   'min_lngth': 251.0,
#   'mean_lngth': 361.3047337278106,
#   'max_wgt': 1.28,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.6197041420118343},
#  'CLEARNOSE SKATE': {'max_lngth': 511.0,
#   'min_lngth': 317.0,
#   'mean_lngth': 421.0,
#   'max_wgt': 3.1,
#   'min_wgt': 1.2,
#   'mean_wgt': 1.9014285714285715},
#  'COBIA': {'max_lngth': 1592.0,
#   'min_lngth': 765.0,
#   'mean_lngth': 981.472972972973,
#   'max_wgt': 28.0,
#   'min_wgt': 4.7,
#   'mean_wgt': 10.787297297297298},
#  'COMMON CARP': {'max_lngth': 840.0,
#   'min_lngth': 275.0,
#   'mean_lngth': 571.2857142857143,
#   'max_wgt': 11.0,
#   'min_wgt': 0.5,
#   'mean_wgt': 3.860714285714286},
#  'COMMON SNOOK': {'max_lngth': 815.0,
#   'min_lngth': 465.0,
#   'mean_lngth': 707.4505494505495,
#   'max_wgt': 5.64,
#   'min_wgt': 0.84,
#   'mean_wgt': 3.546923076923077},
#  'CONEY': {'max_lngth': 233.0,
#   'min_lngth': 233.0,
#   'mean_lngth': 233.0,
#   'max_wgt': 0.22,
#   'min_wgt': 0.22,
#   'mean_wgt': 0.22},
#  'CONGER EEL': {'max_lngth': 1275.0,
#   'min_lngth': 460.0,
#   'mean_lngth': 844.5714285714286,
#   'max_wgt': 3.88,
#   'min_wgt': 0.25,
#   'mean_wgt': 1.7985714285714285},
#  'COTTONWICK': {'max_lngth': 229.0,
#   'min_lngth': 228.0,
#   'mean_lngth': 228.33333333333334,
#   'max_wgt': 0.22,
#   'min_wgt': 0.22,
#   'mean_wgt': 0.22},
#  'COWNOSE RAY': {'max_lngth': 595.0,
#   'min_lngth': 595.0,
#   'mean_lngth': 595.0,
#   'max_wgt': 10.9,
#   'min_wgt': 10.9,
#   'mean_wgt': 10.9},
#  'CREOLE-FISH': {'max_lngth': 274.0,
#   'min_lngth': 239.0,
#   'mean_lngth': 260.27272727272725,
#   'max_wgt': 0.46,
#   'min_wgt': 0.34,
#   'mean_wgt': 0.4018181818181818},
#  'CREVALLE JACK': {'max_lngth': 952.0,
#   'min_lngth': 180.0,
#   'mean_lngth': 389.04501607717043,
#   'max_wgt': 13.01,
#   'min_wgt': 0.12,
#   'mean_wgt': 1.5682636655948554},
#  'CUBBYU': {'max_lngth': 262.0,
#   'min_lngth': 233.0,
#   'mean_lngth': 254.75,
#   'max_wgt': 0.66,
#   'min_wgt': 0.26,
#   'mean_wgt': 0.36},
#  'CUBERA SNAPPER': {'max_lngth': 890.0,
#   'min_lngth': 284.0,
#   'mean_lngth': 568.0,
#   'max_wgt': 13.5,
#   'min_wgt': 0.32,
#   'mean_wgt': 4.343333333333333},
#  'CUNNER': {'max_lngth': 405.0,
#   'min_lngth': 112.0,
#   'mean_lngth': 233.91186440677967,
#   'max_wgt': 1.1,
#   'min_wgt': 0.03,
#   'mean_wgt': 0.27647457627118643},
#  'CUSK': {'max_lngth': 782.0,
#   'min_lngth': 223.0,
#   'mean_lngth': 535.9542483660131,
#   'max_wgt': 5.5,
#   'min_wgt': 0.12,
#   'mean_wgt': 1.77031045751634},
#  'DOG SNAPPER': {'max_lngth': 294.0,
#   'min_lngth': 294.0,
#   'mean_lngth': 294.0,
#   'max_wgt': 0.5,
#   'min_wgt': 0.5,
#   'mean_wgt': 0.5},
#  'DOLPHIN': {'max_lngth': 1400.0,
#   'min_lngth': 281.0,
#   'mean_lngth': 612.6941710825132,
#   'max_wgt': 22.76,
#   'min_wgt': 0.22,
#   'mean_wgt': 2.4693338380015137},
#  'FINETOOTH SHARK': {'max_lngth': 636.0,
#   'min_lngth': 570.0,
#   'mean_lngth': 602.2,
#   'max_wgt': 2.88,
#   'min_wgt': 2.0,
#   'mean_wgt': 2.288},
#  'FLORIDA POMPANO': {'max_lngth': 436.0,
#   'min_lngth': 110.0,
#   'mean_lngth': 288.2094594594595,
#   'max_wgt': 1.9,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.6401351351351352},
#  'FRENCH ANGELFISH': {'max_lngth': 368.0,
#   'min_lngth': 368.0,
#   'mean_lngth': 368.0,
#   'max_wgt': 1.78,
#   'min_wgt': 1.78,
#   'mean_wgt': 1.78},
#  'FRENCH GRUNT': {'max_lngth': 296.0,
#   'min_lngth': 249.0,
#   'mean_lngth': 270.0,
#   'max_wgt': 0.38,
#   'min_wgt': 0.28,
#   'mean_wgt': 0.3333333333333333},
#  'FRIGATE MACKEREL': {'max_lngth': 355.0,
#   'min_lngth': 355.0,
#   'mean_lngth': 355.0,
#   'max_wgt': 0.68,
#   'min_wgt': 0.68,
#   'mean_wgt': 0.68},
#  'GAFFTOPSAIL CATFISH': {'max_lngth': 581.0,
#   'min_lngth': 194.0,
#   'mean_lngth': 374.60233918128654,
#   'max_wgt': 2.68,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.8949707602339181},
#  'GAG': {'max_lngth': 1125.0,
#   'min_lngth': 515.0,
#   'mean_lngth': 681.5737226277372,
#   'max_wgt': 20.28,
#   'min_wgt': 1.9,
#   'mean_wgt': 4.414846715328467},
#  'GIZZARD SHAD': {'max_lngth': 351.0,
#   'min_lngth': 351.0,
#   'mean_lngth': 351.0,
#   'max_wgt': 0.6,
#   'min_wgt': 0.6,
#   'mean_wgt': 0.6},
#  'GOOSEFISH': {'max_lngth': 688.0,
#   'min_lngth': 558.0,
#   'mean_lngth': 642.5,
#   'max_wgt': 4.91,
#   'min_wgt': 2.61,
#   'mean_wgt': 4.028333333333333},
#  'GRASS PORGY': {'max_lngth': 246.0,
#   'min_lngth': 202.0,
#   'mean_lngth': 218.53846153846155,
#   'max_wgt': 0.38,
#   'min_wgt': 0.18,
#   'mean_wgt': 0.24923076923076926},
#  'GRAY SNAPPER': {'max_lngth': 665.0,
#   'min_lngth': 187.0,
#   'mean_lngth': 308.3551454138702,
#   'max_wgt': 4.9,
#   'min_wgt': 0.12,
#   'mean_wgt': 0.53792225950783},
#  'GRAY TRIGGERFISH': {'max_lngth': 581.0,
#   'min_lngth': 229.0,
#   'mean_lngth': 374.08344370860925,
#   'max_wgt': 5.0,
#   'min_wgt': 0.22,
#   'mean_wgt': 1.303728476821192},
#  'GRAYSBY': {'max_lngth': 370.0,
#   'min_lngth': 220.0,
#   'mean_lngth': 295.53225806451616,
#   'max_wgt': 1.0,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.47161290322580646},
#  'GREAT BARRACUDA': {'max_lngth': 1422.0,
#   'min_lngth': 357.0,
#   'mean_lngth': 840.6879271070615,
#   'max_wgt': 17.76,
#   'min_wgt': 0.26,
#   'mean_wgt': 4.389430523917995},
#  'GREATER AMBERJACK': {'max_lngth': 1425.0,
#   'min_lngth': 292.0,
#   'mean_lngth': 877.004246284501,
#   'max_wgt': 31.77,
#   'min_wgt': 1.0,
#   'mean_wgt': 9.728535031847134},
#  'GULF FLOUNDER': {'max_lngth': 516.0,
#   'min_lngth': 305.0,
#   'mean_lngth': 383.3636363636364,
#   'max_wgt': 1.75,
#   'min_wgt': 0.3,
#   'mean_wgt': 0.6509090909090909},
#  'GULF KINGFISH': {'max_lngth': 450.0,
#   'min_lngth': 168.0,
#   'mean_lngth': 298.48982785602504,
#   'max_wgt': 0.95,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.32142410015649453},
#  'GULF MENHADEN': {'max_lngth': 183.0,
#   'min_lngth': 183.0,
#   'mean_lngth': 183.0,
#   'max_wgt': 0.1,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.1},
#  'HADDOCK': {'max_lngth': 657.0,
#   'min_lngth': 245.0,
#   'mean_lngth': 449.6640912435614,
#   'max_wgt': 2.79,
#   'min_wgt': 0.19,
#   'mean_wgt': 0.9936595535933285},
#  'HARDHEAD CATFISH': {'max_lngth': 558.0,
#   'min_lngth': 200.0,
#   'mean_lngth': 297.2953020134228,
#   'max_wgt': 2.06,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.3940939597315436},
#  'HICKORY SHAD': {'max_lngth': 388.0,
#   'min_lngth': 269.0,
#   'mean_lngth': 325.56666666666666,
#   'max_wgt': 0.66,
#   'min_wgt': 0.25,
#   'mean_wgt': 0.42133333333333334},
#  'HOGFISH': {'max_lngth': 697.0,
#   'min_lngth': 320.0,
#   'mean_lngth': 375.7835820895522,
#   'max_wgt': 6.9,
#   'min_wgt': 0.62,
#   'mean_wgt': 1.0357462686567163},
#  'HOUNDFISH': {'max_lngth': 630.0,
#   'min_lngth': 630.0,
#   'mean_lngth': 630.0,
#   'max_wgt': 0.36,
#   'min_wgt': 0.36,
#   'mean_wgt': 0.36},
#  'HYBRID STRIPED BASS': {'max_lngth': 760.0,
#   'min_lngth': 399.0,
#   'mean_lngth': 574.6666666666666,
#   'max_wgt': 5.44,
#   'min_wgt': 1.02,
#   'mean_wgt': 3.026666666666667},
#  'INSHORE LIZARDFISH': {'max_lngth': 459.0,
#   'min_lngth': 210.0,
#   'mean_lngth': 336.3076923076923,
#   'max_wgt': 0.78,
#   'min_wgt': 0.06,
#   'mean_wgt': 0.33999999999999997},
#  'IRISH POMPANO': {'max_lngth': 291.0,
#   'min_lngth': 116.0,
#   'mean_lngth': 203.125,
#   'max_wgt': 0.52,
#   'min_wgt': 0.08,
#   'mean_wgt': 0.21645833333333334},
#  'JOLTHEAD PORGY': {'max_lngth': 462.0,
#   'min_lngth': 225.0,
#   'mean_lngth': 309.5892857142857,
#   'max_wgt': 2.44,
#   'min_wgt': 0.28,
#   'mean_wgt': 0.7608928571428571},
#  'KING MACKEREL': {'max_lngth': 1432.0,
#   'min_lngth': 117.0,
#   'mean_lngth': 790.3892481810833,
#   'max_wgt': 23.59,
#   'min_wgt': 0.01,
#   'mean_wgt': 4.006984640258691},
#  'KNOBBED PORGY': {'max_lngth': 370.0,
#   'min_lngth': 204.0,
#   'mean_lngth': 278.5131578947368,
#   'max_wgt': 1.25,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.5742105263157895},
#  'LADYFISH': {'max_lngth': 540.0,
#   'min_lngth': 217.0,
#   'mean_lngth': 400.8804347826087,
#   'max_wgt': 1.36,
#   'min_wgt': 0.06,
#   'mean_wgt': 0.5504347826086956},
#  'LANE SNAPPER': {'max_lngth': 455.0,
#   'min_lngth': 195.0,
#   'mean_lngth': 274.9364341085271,
#   'max_wgt': 1.38,
#   'min_wgt': 0.14,
#   'mean_wgt': 0.3622015503875969},
#  'LARGEMOUTH BASS': {'max_lngth': 498.0,
#   'min_lngth': 265.0,
#   'mean_lngth': 361.55,
#   'max_wgt': 1.72,
#   'min_wgt': 0.28,
#   'mean_wgt': 0.82},
#  'LEATHERJACK': {'max_lngth': 187.0,
#   'min_lngth': 187.0,
#   'mean_lngth': 187.0,
#   'max_wgt': 0.05,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.05},
#  'LESSER AMBERJACK': {'max_lngth': 417.0,
#   'min_lngth': 305.0,
#   'mean_lngth': 361.0,
#   'max_wgt': 1.5,
#   'min_wgt': 1.2,
#   'mean_wgt': 1.35},
#  'LIONFISH': {'max_lngth': 420.0,
#   'min_lngth': 142.0,
#   'mean_lngth': 277.1034482758621,
#   'max_wgt': 0.86,
#   'min_wgt': 0.02,
#   'mean_wgt': 0.35735632183908045},
#  'LITTLE SKATE': {'max_lngth': 578.0,
#   'min_lngth': 241.0,
#   'mean_lngth': 386.8333333333333,
#   'max_wgt': 0.7,
#   'min_wgt': 0.59,
#   'mean_wgt': 0.645},
#  'LITTLE TUNNY': {'max_lngth': 875.0,
#   'min_lngth': 269.0,
#   'mean_lngth': 551.3784722222222,
#   'max_wgt': 9.2,
#   'min_wgt': 0.26,
#   'mean_wgt': 2.676451388888889},
#  'LITTLEHEAD PORGY': {'max_lngth': 368.0,
#   'min_lngth': 187.0,
#   'mean_lngth': 253.38740920096853,
#   'max_wgt': 1.0,
#   'min_wgt': 0.14,
#   'mean_wgt': 0.3722033898305085},
#  'LONGHORN SCULPIN': {'max_lngth': 330.0,
#   'min_lngth': 330.0,
#   'mean_lngth': 330.0,
#   'max_wgt': 0.35,
#   'min_wgt': 0.35,
#   'mean_wgt': 0.35},
#  'LONGNOSE GAR': {'max_lngth': 822.0,
#   'min_lngth': 670.0,
#   'mean_lngth': 746.0,
#   'max_wgt': 4.0,
#   'min_wgt': 2.5,
#   'mean_wgt': 3.25},
#  'LONGSPINE PORGY': {'max_lngth': 172.0,
#   'min_lngth': 128.0,
#   'mean_lngth': 150.66666666666666,
#   'max_wgt': 0.15,
#   'min_wgt': 0.08,
#   'mean_wgt': 0.11},
#  'LOOKDOWN': {'max_lngth': 321.0,
#   'min_lngth': 221.0,
#   'mean_lngth': 248.5,
#   'max_wgt': 0.66,
#   'min_wgt': 0.28,
#   'mean_wgt': 0.37},
#  'MARGATE': {'max_lngth': 299.0,
#   'min_lngth': 260.0,
#   'mean_lngth': 283.5,
#   'max_wgt': 0.48,
#   'min_wgt': 0.32,
#   'mean_wgt': 0.42},
#  'MUMMICHOG': {'max_lngth': 83.0,
#   'min_lngth': 83.0,
#   'mean_lngth': 83.0,
#   'max_wgt': 0.05,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.05000000000000001},
#  'MUTTON SNAPPER': {'max_lngth': 783.0,
#   'min_lngth': 256.0,
#   'mean_lngth': 497.6593886462882,
#   'max_wgt': 8.63,
#   'min_wgt': 0.34,
#   'mean_wgt': 2.5341484716157208},
#  'NORTHERN KINGFISH': {'max_lngth': 400.0,
#   'min_lngth': 196.0,
#   'mean_lngth': 269.54696132596683,
#   'max_wgt': 0.64,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.2412707182320442},
#  'NORTHERN PUFFER': {'max_lngth': 342.0,
#   'min_lngth': 121.0,
#   'mean_lngth': 188.9643435980551,
#   'max_wgt': 0.6,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.1920583468395462},
#  'NORTHERN SEAROBIN': {'max_lngth': 428.0,
#   'min_lngth': 97.0,
#   'mean_lngth': 285.6706827309237,
#   'max_wgt': 0.78,
#   'min_wgt': 0.01,
#   'mean_wgt': 0.30502008032128514},
#  'NORTHERN SNAKEHEAD': {'max_lngth': 847.0,
#   'min_lngth': 339.0,
#   'mean_lngth': 592.1320754716982,
#   'max_wgt': 5.9,
#   'min_wgt': 0.2,
#   'mean_wgt': 2.349056603773585},
#  'NORTHERN STARGAZER': {'max_lngth': 391.0,
#   'min_lngth': 391.0,
#   'mean_lngth': 391.0,
#   'max_wgt': 1.38,
#   'min_wgt': 1.38,
#   'mean_wgt': 1.38},
#  'OCEAN POUT': {'max_lngth': 615.0,
#   'min_lngth': 584.0,
#   'mean_lngth': 599.5,
#   'max_wgt': 1.24,
#   'min_wgt': 1.07,
#   'mean_wgt': 1.155},
#  'OCEAN TRIGGERFISH': {'max_lngth': 492.0,
#   'min_lngth': 373.0,
#   'mean_lngth': 417.35,
#   'max_wgt': 2.86,
#   'min_wgt': 1.1,
#   'mean_wgt': 1.686},
#  'OYSTER TOADFISH': {'max_lngth': 362.0,
#   'min_lngth': 190.0,
#   'mean_lngth': 317.3255813953488,
#   'max_wgt': 0.89,
#   'min_wgt': 0.19,
#   'mean_wgt': 0.6730232558139535},
#  'PALOMETA': {'max_lngth': 239.0,
#   'min_lngth': 239.0,
#   'mean_lngth': 239.0,
#   'max_wgt': 0.37,
#   'min_wgt': 0.37,
#   'mean_wgt': 0.36999999999999994},
#  'PERMIT': {'max_lngth': 405.0,
#   'min_lngth': 210.0,
#   'mean_lngth': 332.5238095238095,
#   'max_wgt': 1.5,
#   'min_wgt': 0.3,
#   'mean_wgt': 0.9428571428571428},
#  'PIGFISH': {'max_lngth': 318.0,
#   'min_lngth': 143.0,
#   'mean_lngth': 209.51657940663176,
#   'max_wgt': 0.46,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.18425828970331587},
#  'PINFISH': {'max_lngth': 290.0,
#   'min_lngth': 96.0,
#   'mean_lngth': 171.01448575567358,
#   'max_wgt': 0.52,
#   'min_wgt': 0.02,
#   'mean_wgt': 0.12490101400289716},
#  'POLLOCK': {'max_lngth': 997.0,
#   'min_lngth': 210.0,
#   'mean_lngth': 487.38257575757575,
#   'max_wgt': 10.91,
#   'min_wgt': 0.1,
#   'mean_wgt': 1.6761666666666666},
#  'POMPANO DOLPHIN': {'max_lngth': 473.0,
#   'min_lngth': 298.0,
#   'mean_lngth': 411.8333333333333,
#   'max_wgt': 1.4,
#   'min_wgt': 0.3,
#   'mean_wgt': 0.9133333333333332},
#  'PORKFISH': {'max_lngth': 262.0,
#   'min_lngth': 181.0,
#   'mean_lngth': 236.33333333333334,
#   'max_wgt': 0.44,
#   'min_wgt': 0.12,
#   'mean_wgt': 0.3522222222222222},
#  'PUDDINGWIFE': {'max_lngth': 362.0,
#   'min_lngth': 362.0,
#   'mean_lngth': 362.0,
#   'max_wgt': 0.86,
#   'min_wgt': 0.86,
#   'mean_wgt': 0.86},
#  'PUMPKINSEED': {'max_lngth': 147.0,
#   'min_lngth': 147.0,
#   'mean_lngth': 147.0,
#   'max_wgt': 0.1,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.1},
#  'QUEEN TRIGGERFISH': {'max_lngth': 432.0,
#   'min_lngth': 318.0,
#   'mean_lngth': 372.85714285714283,
#   'max_wgt': 2.12,
#   'min_wgt': 0.86,
#   'mean_wgt': 1.4600000000000002},
#  'RAINBOW RUNNER': {'max_lngth': 728.0,
#   'min_lngth': 283.0,
#   'mean_lngth': 404.2906976744186,
#   'max_wgt': 4.44,
#   'min_wgt': 0.26,
#   'mean_wgt': 0.8859302325581395},
#  'RED DRUM': {'max_lngth': 974.0,
#   'min_lngth': 270.0,
#   'mean_lngth': 527.1066907775769,
#   'max_wgt': 10.43,
#   'min_wgt': 0.22,
#   'mean_wgt': 1.9044339963833636},
#  'RED GROUPER': {'max_lngth': 803.0,
#   'min_lngth': 272.0,
#   'mean_lngth': 577.3694158075601,
#   'max_wgt': 9.5,
#   'min_wgt': 0.35,
#   'mean_wgt': 3.296718213058419},
#  'RED HAKE': {'max_lngth': 658.0,
#   'min_lngth': 243.0,
#   'mean_lngth': 393.0139318885449,
#   'max_wgt': 1.36,
#   'min_wgt': 0.13,
#   'mean_wgt': 0.5055263157894737},
#  'RED HIND': {'max_lngth': 446.0,
#   'min_lngth': 291.0,
#   'mean_lngth': 358.54545454545456,
#   'max_wgt': 1.4,
#   'min_wgt': 0.3,
#   'mean_wgt': 0.7345454545454545},
#  'RED PORGY': {'max_lngth': 438.0,
#   'min_lngth': 200.0,
#   'mean_lngth': 275.60668103448273,
#   'max_wgt': 1.66,
#   'min_wgt': 0.18,
#   'mean_wgt': 0.48310344827586205},
#  'RED SNAPPER': {'max_lngth': 868.0,
#   'min_lngth': 322.0,
#   'mean_lngth': 505.4941655359566,
#   'max_wgt': 11.75,
#   'min_wgt': 0.6,
#   'mean_wgt': 2.6478127544097694},
#  'REDBREAST SUNFISH': {'max_lngth': 201.0,
#   'min_lngth': 201.0,
#   'mean_lngth': 201.0,
#   'max_wgt': 0.16,
#   'min_wgt': 0.16,
#   'mean_wgt': 0.16},
#  'REDTAIL SCAD': {'max_lngth': 288.0,
#   'min_lngth': 275.0,
#   'mean_lngth': 281.5,
#   'max_wgt': 0.42,
#   'min_wgt': 0.36,
#   'mean_wgt': 0.38999999999999996},
#  'ROCK HIND': {'max_lngth': 474.0,
#   'min_lngth': 257.0,
#   'mean_lngth': 314.85714285714283,
#   'max_wgt': 2.1,
#   'min_wgt': 0.26,
#   'mean_wgt': 0.6278571428571429},
#  'ROCK SEA BASS': {'max_lngth': 313.0,
#   'min_lngth': 180.0,
#   'mean_lngth': 255.65,
#   'max_wgt': 0.3,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.19},
#  'ROUND SCAD': {'max_lngth': 740.0,
#   'min_lngth': 117.0,
#   'mean_lngth': 187.90423387096774,
#   'max_wgt': 0.1,
#   'min_wgt': 0.02,
#   'mean_wgt': 0.06328629032258065},
#  'SAILFISH': {'max_lngth': 1676.0,
#   'min_lngth': 1634.0,
#   'mean_lngth': 1655.0,
#   'max_wgt': 42.0,
#   'min_wgt': 20.04,
#   'mean_wgt': 31.02},
#  'SAILORS CHOICE': {'max_lngth': 300.0,
#   'min_lngth': 197.0,
#   'mean_lngth': 240.23076923076923,
#   'max_wgt': 0.58,
#   'min_wgt': 0.12,
#   'mean_wgt': 0.28615384615384615},
#  'SAND DRUM': {'max_lngth': 290.0,
#   'min_lngth': 205.0,
#   'mean_lngth': 238.57142857142858,
#   'max_wgt': 0.32,
#   'min_wgt': 0.12,
#   'mean_wgt': 0.25},
#  'SAND PERCH': {'max_lngth': 277.0,
#   'min_lngth': 149.0,
#   'mean_lngth': 225.4225941422594,
#   'max_wgt': 0.34,
#   'min_wgt': 0.06,
#   'mean_wgt': 0.17556485355648535},
#  'SAND SEATROUT': {'max_lngth': 435.0,
#   'min_lngth': 198.0,
#   'mean_lngth': 278.9338781575037,
#   'max_wgt': 0.8,
#   'min_wgt': 0.08,
#   'mean_wgt': 0.22657503714710256},
#  'SAND TILEFISH': {'max_lngth': 532.0,
#   'min_lngth': 330.0,
#   'mean_lngth': 421.23809523809524,
#   'max_wgt': 1.2,
#   'min_wgt': 0.25,
#   'mean_wgt': 0.6223809523809524},
#  'SAUCEREYE PORGY': {'max_lngth': 370.0,
#   'min_lngth': 237.0,
#   'mean_lngth': 303.7,
#   'max_wgt': 1.18,
#   'min_wgt': 0.32,
#   'mean_wgt': 0.72},
#  'SCAMP': {'max_lngth': 818.0,
#   'min_lngth': 319.0,
#   'mean_lngth': 491.888198757764,
#   'max_wgt': 7.0,
#   'min_wgt': 0.62,
#   'mean_wgt': 1.989503105590062},
#  'SCHOOLMASTER': {'max_lngth': 440.0,
#   'min_lngth': 219.0,
#   'mean_lngth': 305.6923076923077,
#   'max_wgt': 1.74,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.7230769230769231},
#  'SCRAWLED FILEFISH': {'max_lngth': 460.0,
#   'min_lngth': 445.0,
#   'mean_lngth': 455.0,
#   'max_wgt': 0.7,
#   'min_wgt': 0.5,
#   'mean_wgt': 0.6333333333333333},
#  'SCUP': {'max_lngth': 439.0,
#   'min_lngth': 136.0,
#   'mean_lngth': 267.0712069247101,
#   'max_wgt': 1.5,
#   'min_wgt': 0.08,
#   'mean_wgt': 0.43770972834667105},
#  'SEA BREAM': {'max_lngth': 259.0,
#   'min_lngth': 242.0,
#   'mean_lngth': 250.5,
#   'max_wgt': 0.4,
#   'min_wgt': 0.34,
#   'mean_wgt': 0.37},
#  'SEA RAVEN': {'max_lngth': 572.0,
#   'min_lngth': 422.0,
#   'mean_lngth': 497.0,
#   'max_wgt': 2.49,
#   'min_wgt': 1.21,
#   'mean_wgt': 1.85},
#  'SHEEPSHEAD': {'max_lngth': 598.0,
#   'min_lngth': 156.0,
#   'mean_lngth': 355.95047461824186,
#   'max_wgt': 5.4,
#   'min_wgt': 0.1,
#   'mean_wgt': 1.1963433759801898},
#  'SHEEPSHEAD PORGY': {'max_lngth': 309.0,
#   'min_lngth': 309.0,
#   'mean_lngth': 309.0,
#   'max_wgt': 0.7,
#   'min_wgt': 0.7,
#   'mean_wgt': 0.7},
#  'SHORT BIGEYE': {'max_lngth': 245.0,
#   'min_lngth': 211.0,
#   'mean_lngth': 228.0,
#   'max_wgt': 0.36,
#   'min_wgt': 0.28,
#   'mean_wgt': 0.32},
#  'SILK SNAPPER': {'max_lngth': 473.0,
#   'min_lngth': 274.0,
#   'mean_lngth': 323.0,
#   'max_wgt': 1.8,
#   'min_wgt': 0.3,
#   'mean_wgt': 0.5763157894736842},
#  'SILKY SHARK': {'max_lngth': 695.0,
#   'min_lngth': 695.0,
#   'mean_lngth': 695.0,
#   'max_wgt': 3.3,
#   'min_wgt': 3.3,
#   'mean_wgt': 3.3},
#  'SILVER HAKE': {'max_lngth': 645.0,
#   'min_lngth': 224.0,
#   'mean_lngth': 376.937106918239,
#   'max_wgt': 2.39,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.4686163522012579},
#  'SILVER PERCH': {'max_lngth': 270.0,
#   'min_lngth': 120.0,
#   'mean_lngth': 178.69,
#   'max_wgt': 0.2,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.0866},
#  'SILVER PORGY': {'max_lngth': 270.0,
#   'min_lngth': 245.0,
#   'mean_lngth': 257.5,
#   'max_wgt': 0.56,
#   'min_wgt': 0.42,
#   'mean_wgt': 0.49},
#  'SILVER SEATROUT': {'max_lngth': 550.0,
#   'min_lngth': 249.0,
#   'mean_lngth': 308.5,
#   'max_wgt': 1.5,
#   'min_wgt': 0.14,
#   'mean_wgt': 0.35444444444444445},
#  'SKIPJACK TUNA': {'max_lngth': 772.0,
#   'min_lngth': 294.0,
#   'mean_lngth': 529.4153846153846,
#   'max_wgt': 8.3,
#   'min_wgt': 0.5,
#   'mean_wgt': 3.3173846153846154},
#  'SMOOTH DOGFISH': {'max_lngth': 1008.0,
#   'min_lngth': 364.0,
#   'mean_lngth': 569.8658536585366,
#   'max_wgt': 5.08,
#   'min_wgt': 0.27,
#   'mean_wgt': 1.1907317073170731},
#  'SMOOTH PUFFER': {'max_lngth': 554.0,
#   'min_lngth': 306.0,
#   'mean_lngth': 445.05263157894734,
#   'max_wgt': 2.92,
#   'min_wgt': 0.45,
#   'mean_wgt': 1.5342105263157895},
#  'SNOWY GROUPER': {'max_lngth': 1153.0,
#   'min_lngth': 331.0,
#   'mean_lngth': 698.3333333333334,
#   'max_wgt': 24.0,
#   'min_wgt': 0.58,
#   'mean_wgt': 7.061111111111111},
#  'SOUTHERN FLOUNDER': {'max_lngth': 800.0,
#   'min_lngth': 276.0,
#   'mean_lngth': 410.86596858638745,
#   'max_wgt': 4.5,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.8439790575916231},
#  'SOUTHERN HAKE': {'max_lngth': 534.0,
#   'min_lngth': 534.0,
#   'mean_lngth': 534.0,
#   'max_wgt': 1.18,
#   'min_wgt': 1.18,
#   'mean_wgt': 1.18},
#  'SOUTHERN KINGFISH': {'max_lngth': 410.0,
#   'min_lngth': 124.0,
#   'mean_lngth': 274.440999397953,
#   'max_wgt': 0.85,
#   'min_wgt': 0.02,
#   'mean_wgt': 0.25051173991571346},
#  'SOUTHERN PUFFER': {'max_lngth': 271.0,
#   'min_lngth': 171.0,
#   'mean_lngth': 235.71875,
#   'max_wgt': 0.36,
#   'min_wgt': 0.08,
#   'mean_wgt': 0.26},
#  'SOUTHERN SENNET': {'max_lngth': 416.0,
#   'min_lngth': 386.0,
#   'mean_lngth': 401.0,
#   'max_wgt': 0.32,
#   'min_wgt': 0.28,
#   'mean_wgt': 0.30000000000000004},
#  'SOUTHERN STINGRAY': {'max_lngth': 785.0,
#   'min_lngth': 406.0,
#   'mean_lngth': 540.25,
#   'max_wgt': 18.78,
#   'min_wgt': 1.38,
#   'mean_wgt': 7.5925},
#  'SPANISH HOGFISH': {'max_lngth': 390.0,
#   'min_lngth': 390.0,
#   'mean_lngth': 390.0,
#   'max_wgt': 0.75,
#   'min_wgt': 0.75,
#   'mean_wgt': 0.75},
#  'SPANISH MACKEREL': {'max_lngth': 820.0,
#   'min_lngth': 245.0,
#   'mean_lngth': 398.1535569693464,
#   'max_wgt': 3.5,
#   'min_wgt': 0.14,
#   'mean_wgt': 0.6095213996529786},
#  'SPANISH SARDINE': {'max_lngth': 210.0,
#   'min_lngth': 196.0,
#   'mean_lngth': 204.56521739130434,
#   'max_wgt': 0.12,
#   'min_wgt': 0.12,
#   'mean_wgt': 0.12},
#  'SPECKLED HIND': {'max_lngth': 338.0,
#   'min_lngth': 308.0,
#   'mean_lngth': 319.3333333333333,
#   'max_wgt': 0.7,
#   'min_wgt': 0.5,
#   'mean_wgt': 0.5666666666666667},
#  'SPINNER SHARK': {'max_lngth': 1715.0,
#   'min_lngth': 568.0,
#   'mean_lngth': 939.3529411764706,
#   'max_wgt': 50.8,
#   'min_wgt': 1.7,
#   'mean_wgt': 11.785294117647059},
#  'SPINY DOGFISH': {'max_lngth': 898.0,
#   'min_lngth': 603.0,
#   'mean_lngth': 719.927927927928,
#   'max_wgt': 4.15,
#   'min_wgt': 1.25,
#   'mean_wgt': 2.3294594594594593},
#  'SPOT': {'max_lngth': 288.0,
#   'min_lngth': 102.0,
#   'mean_lngth': 191.91233837387685,
#   'max_wgt': 0.38,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.1287069910146833},
#  'SPOTFIN HOGFISH': {'max_lngth': 304.0,
#   'min_lngth': 259.0,
#   'mean_lngth': 281.5,
#   'max_wgt': 0.46,
#   'min_wgt': 0.34,
#   'mean_wgt': 0.4},
#  'SPOTTAIL PINFISH': {'max_lngth': 311.0,
#   'min_lngth': 174.0,
#   'mean_lngth': 240.36521739130436,
#   'max_wgt': 0.82,
#   'min_wgt': 0.14,
#   'mean_wgt': 0.3923478260869565},
#  'SPOTTED HAKE': {'max_lngth': 391.0,
#   'min_lngth': 216.0,
#   'mean_lngth': 314.90909090909093,
#   'max_wgt': 0.48,
#   'min_wgt': 0.11,
#   'mean_wgt': 0.3059090909090909},
#  'SPOTTED SEATROUT': {'max_lngth': 684.0,
#   'min_lngth': 242.0,
#   'mean_lngth': 421.48207683652146,
#   'max_wgt': 3.3,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.754705031345443},
#  'SQUIRRELFISH': {'max_lngth': 254.0,
#   'min_lngth': 214.0,
#   'mean_lngth': 240.66666666666666,
#   'max_wgt': 0.35,
#   'min_wgt': 0.26,
#   'mean_wgt': 0.32},
#  'STRIPED BASS': {'max_lngth': 1257.0,
#   'min_lngth': 381.0,
#   'mean_lngth': 638.9812961011592,
#   'max_wgt': 21.0,
#   'min_wgt': 0.6,
#   'mean_wgt': 3.491601685985248},
#  'STRIPED MOJARRA': {'max_lngth': 305.0,
#   'min_lngth': 182.0,
#   'mean_lngth': 226.27272727272728,
#   'max_wgt': 0.42,
#   'min_wgt': 0.18,
#   'mean_wgt': 0.25636363636363635},
#  'STRIPED MULLET': {'max_lngth': 476.0,
#   'min_lngth': 79.0,
#   'mean_lngth': 280.31259720062206,
#   'max_wgt': 1.4,
#   'min_wgt': 0.02,
#   'mean_wgt': 0.37161741835147744},
#  'STRIPED SEAROBIN': {'max_lngth': 447.0,
#   'min_lngth': 168.0,
#   'mean_lngth': 331.34150943396224,
#   'max_wgt': 1.12,
#   'min_wgt': 0.06,
#   'mean_wgt': 0.5189433962264152},
#  'SUMMER FLOUNDER': {'max_lngth': 821.0,
#   'min_lngth': 182.0,
#   'mean_lngth': 494.95271739130436,
#   'max_wgt': 5.8,
#   'min_wgt': 0.05,
#   'mean_wgt': 1.3280706521739132},
#  'SWORDFISH': {'max_lngth': 1905.0,
#   'min_lngth': 1430.0,
#   'mean_lngth': 1810.0,
#   'max_wgt': 89.8,
#   'min_wgt': 16.92,
#   'mean_wgt': 75.224},
#  'TAUTOG': {'max_lngth': 703.0,
#   'min_lngth': 156.0,
#   'mean_lngth': 445.0207715133531,
#   'max_wgt': 7.3,
#   'min_wgt': 0.07,
#   'mean_wgt': 1.7902195845697328},
#  'THRESHER SHARK': {'max_lngth': 2444.0,
#   'min_lngth': 2444.0,
#   'mean_lngth': 2444.0,
#   'max_wgt': 368.38,
#   'min_wgt': 368.38,
#   'mean_wgt': 368.38},
#  'TILEFISH': {'max_lngth': 837.0,
#   'min_lngth': 277.0,
#   'mean_lngth': 551.9090909090909,
#   'max_wgt': 7.6,
#   'min_wgt': 0.2,
#   'mean_wgt': 2.5738636363636362},
#  'TOMTATE': {'max_lngth': 307.0,
#   'min_lngth': 135.0,
#   'mean_lngth': 209.49444444444444,
#   'max_wgt': 0.3,
#   'min_wgt': 0.08,
#   'mean_wgt': 0.18490740740740744},
#  'TRIPLETAIL': {'max_lngth': 680.0,
#   'min_lngth': 263.0,
#   'mean_lngth': 519.6197183098592,
#   'max_wgt': 8.5,
#   'min_wgt': 0.4,
#   'mean_wgt': 3.526619718309859},
#  'UNICORN FILEFISH': {'max_lngth': 458.0,
#   'min_lngth': 444.0,
#   'mean_lngth': 451.0,
#   'max_wgt': 1.0,
#   'min_wgt': 0.96,
#   'mean_wgt': 0.98},
#  'VERMILION SNAPPER': {'max_lngth': 510.0,
#   'min_lngth': 121.0,
#   'mean_lngth': 302.7456395348837,
#   'max_wgt': 2.3,
#   'min_wgt': 0.03,
#   'mean_wgt': 0.5022698643410852},
#  'WAHOO': {'max_lngth': 1826.0,
#   'min_lngth': 503.0,
#   'mean_lngth': 1182.9851485148515,
#   'max_wgt': 37.65,
#   'min_wgt': 0.66,
#   'mean_wgt': 11.568960396039603},
#  'WEAKFISH': {'max_lngth': 718.0,
#   'min_lngth': 178.0,
#   'mean_lngth': 378.60090702947844,
#   'max_wgt': 3.9,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.6482993197278911},
#  'WHITE CATFISH': {'max_lngth': 486.0,
#   'min_lngth': 185.0,
#   'mean_lngth': 351.48275862068965,
#   'max_wgt': 2.2,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.8572413793103448},
#  'WHITE CRAPPIE': {'max_lngth': 298.0,
#   'min_lngth': 127.0,
#   'mean_lngth': 236.5625,
#   'max_wgt': 0.45,
#   'min_wgt': 0.1,
#   'mean_wgt': 0.209375},
#  'WHITE GRUNT': {'max_lngth': 434.0,
#   'min_lngth': 161.0,
#   'mean_lngth': 257.5293427230047,
#   'max_wgt': 1.9,
#   'min_wgt': 0.08,
#   'mean_wgt': 0.3659565727699531},
#  'WHITE HAKE': {'max_lngth': 752.0,
#   'min_lngth': 228.0,
#   'mean_lngth': 534.2285714285714,
#   'max_wgt': 3.92,
#   'min_wgt': 0.11,
#   'mean_wgt': 1.7005714285714284},
#  'WHITE MULLET': {'max_lngth': 337.0,
#   'min_lngth': 119.0,
#   'mean_lngth': 254.73333333333332,
#   'max_wgt': 0.5,
#   'min_wgt': 0.02,
#   'mean_wgt': 0.2703809523809524},
#  'WHITE PERCH': {'max_lngth': 355.0,
#   'min_lngth': 104.0,
#   'mean_lngth': 210.24384112619407,
#   'max_wgt': 0.7,
#   'min_wgt': 0.05,
#   'mean_wgt': 0.174851684263449},
#  'WHITEBONE PORGY': {'max_lngth': 397.0,
#   'min_lngth': 205.0,
#   'mean_lngth': 288.3189655172414,
#   'max_wgt': 1.5,
#   'min_wgt': 0.18,
#   'mean_wgt': 0.5938793103448275},
#  'WINDOWPANE': {'max_lngth': 333.0,
#   'min_lngth': 251.0,
#   'mean_lngth': 305.6666666666667,
#   'max_wgt': 0.44,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.36000000000000004},
#  'WINTER FLOUNDER': {'max_lngth': 445.0,
#   'min_lngth': 251.0,
#   'mean_lngth': 363.32474226804123,
#   'max_wgt': 1.2,
#   'min_wgt': 0.23,
#   'mean_wgt': 0.6435051546391752},
#  'WINTER SKATE': {'max_lngth': 513.0,
#   'min_lngth': 327.0,
#   'mean_lngth': 423.6363636363636,
#   'max_wgt': 2.16,
#   'min_wgt': 1.25,
#   'mean_wgt': 1.7154545454545456},
#  'YELLOW BULLHEAD': {'max_lngth': 385.0,
#   'min_lngth': 385.0,
#   'mean_lngth': 385.0,
#   'max_wgt': 1.0,
#   'min_wgt': 1.0,
#   'mean_wgt': 1.0},
#  'YELLOW CHUB': {'max_lngth': 211.0,
#   'min_lngth': 211.0,
#   'mean_lngth': 211.0,
#   'max_wgt': 0.2,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.2},
#  'YELLOW JACK': {'max_lngth': 793.0,
#   'min_lngth': 160.0,
#   'mean_lngth': 385.40625,
#   'max_wgt': 7.38,
#   'min_wgt': 0.06,
#   'mean_wgt': 1.329609375},
#  'YELLOW PERCH': {'max_lngth': 303.0,
#   'min_lngth': 180.0,
#   'mean_lngth': 204.125,
#   'max_wgt': 0.4,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.21125000000000002},
#  'YELLOWEDGE GROUPER': {'max_lngth': 905.0,
#   'min_lngth': 525.0,
#   'mean_lngth': 635.4,
#   'max_wgt': 10.45,
#   'min_wgt': 1.8,
#   'mean_wgt': 4.09},
#  'YELLOWFIN MENHADEN': {'max_lngth': 330.0,
#   'min_lngth': 271.0,
#   'mean_lngth': 298.63157894736844,
#   'max_wgt': 0.56,
#   'min_wgt': 0.44,
#   'mean_wgt': 0.5094736842105263},
#  'YELLOWFIN TUNA': {'max_lngth': 1473.0,
#   'min_lngth': 562.0,
#   'mean_lngth': 884.9783281733746,
#   'max_wgt': 51.5,
#   'min_wgt': 3.28,
#   'mean_wgt': 13.240626934984519},
#  'YELLOWTAIL SNAPPER': {'max_lngth': 486.0,
#   'min_lngth': 223.0,
#   'mean_lngth': 300.2670906200318,
#   'max_wgt': 1.8,
#   'min_wgt': 0.2,
#   'mean_wgt': 0.48930047694753576}}

# %%
dict_chance = {} #这个字典是每种鱼出现的概率（一年中）
for species in df1['common'].unique():
    zz = df1.loc[df1['common']== species]['common'].count()
    temp_dict1 = {species:round((zz/len(df1)*100),3)}
    dict_chance.update(temp_dict1)
dict_chance
# Out:
# {'WHITE CATFISH': 0.018,
#  'SPOTTED SEATROUT': 3.78,
#  'BLACK MARGATE': 0.017,
#  'SHEEPSHEAD': 1.472,
#  'ATLANTIC CROAKER': 5.137,
#  'FLORIDA POMPANO': 0.27,
#  'LOOKDOWN': 0.01,
#  'PINFISH': 1.258,
#  'BLUEFISH': 2.542,
#  'IRISH POMPANO': 0.058,
#  'CREVALLE JACK': 0.189,
#  'CERO': 0.088,
#  'GULF KINGFISH': 0.388,
#  'SPOT': 2.773,
#  'BLUE RUNNER': 0.524,
#  'BLACK DRUM': 0.525,
#  'COMMON SNOOK': 0.055,
#  'SPANISH MACKEREL': 4.203,
#  'SOUTHERN KINGFISH': 2.019,
#  'STRIPED MULLET': 0.391,
#  'WHITE GRUNT': 2.071,
#  'GRAY SNAPPER': 2.173,
#  'YELLOW JACK': 0.078,
#  'BERMUDA CHUB': 0.025,
#  'BLUESTRIPED GRUNT': 0.027,
#  'SPOTTAIL PINFISH': 0.14,
#  'LADYFISH': 0.168,
#  'SOUTHERN FLOUNDER': 0.58,
#  'GREAT BARRACUDA': 0.267,
#  'SAND DRUM': 0.004,
#  'LITTLE TUNNY': 0.875,
#  'SAND SEATROUT': 0.818,
#  'KING MACKEREL': 1.503,
#  'YELLOWTAIL SNAPPER': 0.764,
#  'BLACKFIN TUNA': 0.493,
#  'LANE SNAPPER': 0.784,
#  'COBIA': 0.135,
#  'GREATER AMBERJACK': 0.286,
#  'DOLPHIN': 2.408,
#  'ALMACO JACK': 0.33,
#  'BLACKBELLY ROSEFISH': 0.075,
#  'VERMILION SNAPPER': 2.508,
#  'MUTTON SNAPPER': 0.139,
#  'CUBERA SNAPPER': 0.004,
#  'WEAKFISH': 0.268,
#  'SPINNER SHARK': 0.01,
#  'TRIPLETAIL': 0.043,
#  'BLACKTIP SHARK': 0.036,
#  'GRAY TRIGGERFISH': 0.918,
#  'BLACK SEA BASS': 9.696,
#  'PERMIT': 0.013,
#  'BLACKNOSE SHARK': 0.016,
#  'SAILFISH': 0.001,
#  'WAHOO': 0.123,
#  'SMOOTH PUFFER': 0.012,
#  'RED DRUM': 1.68,
#  'SILVER PERCH': 0.061,
#  'SCHOOLMASTER': 0.008,
#  'WHITEBONE PORGY': 0.07,
#  'RED PORGY': 0.564,
#  'PIGFISH': 0.348,
#  'JOLTHEAD PORGY': 0.068,
#  'TILEFISH': 0.027,
#  'GRAYSBY': 0.038,
#  'RAINBOW RUNNER': 0.052,
#  'BONNETHEAD': 0.036,
#  'LITTLEHEAD PORGY': 0.251,
#  'SAND TILEFISH': 0.013,
#  'BLACK CRAPPIE': 0.042,
#  'WHITE PERCH': 1.209,
#  'SCAMP': 0.098,
#  'BLACKWING SEAROBIN': 0.001,
#  'ATLANTIC SPADEFISH': 0.265,
#  'TOMTATE': 0.328,
#  'HARDHEAD CATFISH': 0.091,
#  'WHITE MULLET': 0.064,
#  'ATLANTIC THREAD HERRING': 0.338,
#  'NORTHERN KINGFISH': 0.11,
#  'BALLYHOO': 0.015,
#  'SOUTHERN SENNET': 0.001,
#  'SHORT BIGEYE': 0.001,
#  'RED GROUPER': 0.354,
#  'BANK SEA BASS': 0.024,
#  'SAND PERCH': 0.145,
#  'SOUTHERN PUFFER': 0.019,
#  'HOGFISH': 0.081,
#  'KNOBBED PORGY': 0.046,
#  'AFRICAN POMPANO': 0.016,
#  'BIGEYE': 0.006,
#  'SAUCEREYE PORGY': 0.006,
#  'SHEEPSHEAD PORGY': 0.001,
#  'SKIPJACK TUNA': 0.039,
#  'SAILORS CHOICE': 0.024,
#  'GRASS PORGY': 0.008,
#  'GULF FLOUNDER': 0.04,
#  'PUDDINGWIFE': 0.001,
#  'OCEAN TRIGGERFISH': 0.012,
#  'ROUND SCAD': 0.603,
#  'LARGEMOUTH BASS': 0.012,
#  'STRIPED BASS': 2.307,
#  'TAUTOG': 2.048,
#  'HADDOCK': 4.955,
#  'CUSK': 0.372,
#  'WHITE HAKE': 0.021,
#  'POLLOCK': 0.802,
#  'ATLANTIC COD': 0.239,
#  'CUNNER': 0.179,
#  'ACADIAN REDFISH': 1.624,
#  'SEA RAVEN': 0.001,
#  'SCUP': 11.162,
#  'RED HAKE': 0.393,
#  'CHANNEL CATFISH': 0.175,
#  'SPINY DOGFISH': 0.067,
#  'PUMPKINSEED': 0.001,
#  'YELLOW PERCH': 0.024,
#  'BLUE CATFISH': 0.317,
#  'NORTHERN SNAKEHEAD': 0.032,
#  'CONGER EEL': 0.009,
#  'SUMMER FLOUNDER': 2.236,
#  'SILVER HAKE': 0.193,
#  'ATLANTIC MENHADEN': 0.578,
#  'ATLANTIC HERRING': 0.103,
#  'STRIPED SEAROBIN': 0.322,
#  'WINTER FLOUNDER': 0.118,
#  'OCEAN POUT': 0.001,
#  'AMERICAN EEL': 0.011,
#  'FRIGATE MACKEREL': 0.001,
#  'UNICORN FILEFISH': 0.001,
#  'BLACKFIN SNAPPER': 0.004,
#  'FINETOOTH SHARK': 0.003,
#  'SNOWY GROUPER': 0.011,
#  'SILK SNAPPER': 0.012,
#  'FRENCH ANGELFISH': 0.001,
#  'LIONFISH': 0.053,
#  'SQUIRRELFISH': 0.002,
#  'SILVER SEATROUT': 0.011,
#  'DOG SNAPPER': 0.001,
#  'REDTAIL SCAD': 0.004,
#  'BAR JACK': 0.002,
#  'YELLOWFIN TUNA': 0.785,
#  'COWNOSE RAY': 0.002,
#  'ATLANTIC SHARPNOSE SHARK': 0.08,
#  'NORTHERN PUFFER': 0.375,
#  'BLUEFIN TUNA': 0.104,
#  'BIGEYE TUNA': 0.061,
#  'ATLANTIC BONITO': 0.067,
#  'ROCK SEA BASS': 0.012,
#  'GAFFTOPSAIL CATFISH': 0.104,
#  'YELLOWEDGE GROUPER': 0.003,
#  'BEARDED BROTULA': 0.001,
#  'ATLANTIC STINGRAY': 0.004,
#  'INSHORE LIZARDFISH': 0.008,
#  'ROCK HIND': 0.009,
#  'POMPANO DOLPHIN': 0.004,
#  'BANDED RUDDERFISH': 0.066,
#  'HOUNDFISH': 0.002,
#  'GAG': 0.416,
#  'NORTHERN SEAROBIN': 0.151,
#  'SPOTTED HAKE': 0.013,
#  'SMOOTH DOGFISH': 0.05,
#  'CHUB MACKEREL': 0.205,
#  'WINTER SKATE': 0.007,
#  'HICKORY SHAD': 0.018,
#  'CLEARNOSE SKATE': 0.004,
#  'ATLANTIC MACKEREL': 4.797,
#  'GOOSEFISH': 0.004,
#  'LITTLE SKATE': 0.004,
#  'COMMON CARP': 0.009,
#  'MUMMICHOG': 0.004,
#  'BLUELINE TILEFISH': 0.319,
#  'YELLOW BULLHEAD': 0.001,
#  'NORTHERN STARGAZER': 0.001,
#  'WINDOWPANE': 0.002,
#  'THRESHER SHARK': 0.001,
#  'ATLANTIC CUTLASSFISH': 0.678,
#  'BLACK GROUPER': 0.015,
#  'QUEEN TRIGGERFISH': 0.004,
#  'RED SNAPPER': 2.239,
#  'FRENCH GRUNT': 0.004,
#  'RED HIND': 0.007,
#  'CONEY': 0.001,
#  'BIGSCALE POMFRET': 0.001,
#  'OYSTER TOADFISH': 0.026,
#  'SOUTHERN STINGRAY': 0.002,
#  'BLUE MARLIN': 0.001,
#  'ATLANTIC NEEDLEFISH': 0.001,
#  'GULF MENHADEN': 0.027,
#  'LEATHERJACK': 0.016,
#  'SPANISH SARDINE': 0.014,
#  'ATLANTIC BUMPER': 0.04,
#  'SOUTHERN HAKE': 0.001,
#  'STRIPED MOJARRA': 0.007,
#  'CUBBYU': 0.002,
#  'BARRELFISH': 0.001,
#  'BLUEGILL': 0.004,
#  'GIZZARD SHAD': 0.001,
#  'ALBACORE': 0.008,
#  'BROWN BULLHEAD': 0.007,
#  'LONGSPINE PORGY': 0.002,
#  'PALOMETA': 0.002,
#  'MARGATE': 0.002,
#  'HYBRID STRIPED BASS': 0.002,
#  'CAESAR GRUNT': 0.001,
#  'LESSER AMBERJACK': 0.001,
#  'BLACK JACK': 0.001,
#  'SPANISH HOGFISH': 0.001,
#  'ATLANTIC MOONFISH': 0.002,
#  'BLUE ANGELFISH': 0.001,
#  'SWORDFISH': 0.003,
#  'SPOTFIN HOGFISH': 0.002,
#  'CREOLE-FISH': 0.007,
#  'COTTONWICK': 0.002,
#  'BULL SHARK': 0.002,
#  'ATLANTIC SILVERSIDE': 0.004,
#  'LONGHORN SCULPIN': 0.001,
#  'REDBREAST SUNFISH': 0.001,
#  'SILVER PORGY': 0.001,
#  'BLUE PARROTFISH': 0.001,
#  'SCRAWLED FILEFISH': 0.002,
#  'LONGNOSE GAR': 0.001,
#  'SPECKLED HIND': 0.004,
#  'SILKY SHARK': 0.001,
#  'WHITE CRAPPIE': 0.019,
#  'PORKFISH': 0.005,
#  'SEA BREAM': 0.001,
#  'YELLOWFIN MENHADEN': 0.012,
#  'CAROLINA HAKE': 0.001,
#  'YELLOW CHUB': 0.002}

# %% [markdown]
# # 模拟

# %%
prob_threshold=0.01 #%
fish_species=list(filter(lambda x:x[1]>0.01,dict_chance.items()))

# %%
species_keyset=set(dict(fish_species).keys())
feature_keyset=set(fish_stat.keys())
fish_key=species_keyset.intersection(feature_keyset)
len(fish_key)
# Out:
# 139

# %%
species_result=dict(filter(lambda x:x[0] in fish_key,fish_species))
feature_result=dict(filter(lambda x:x[0] in fish_key,fish_stat.items()))
species_result_sort=sorted(species_result.items(),key=lambda x:x[1], reverse=False)

# %%
species_prob=dict()
accSum=0
total=sum(species_result.values())
for s in species_result_sort:
    species_prob[s[0]]=[accSum/total,(accSum+s[1])/total]
    accSum+=s[1]

# %%
import random

# %%
def getSpecies(prob):
    for (k,v) in species_prob.items():
        if prob>=v[0] and prob<v[1]:
            return k
    else:
        return None
    
def generateInfor(prob):
    species=getSpecies(prob)
    feature=feature_result[species]
    length=random.uniform(feature['min_lngth'],feature['max_lngth'])
    weight=random.uniform(feature['min_wgt'],feature['max_wgt'])
    return species,length,weight

# %%
people_count=5
fishing_time=3

# %%
result=[]
for p in range(people_count):
    print('*'*10,'PERSON ',p,'*'*10)
    for t in range(fishing_time):
        prob=random.random()
        info=generateInfor(prob)
        print(info)
        result.append((p,info))
result
# Out:
# ********** PERSON  0 **********
# ('SAND SEATROUT', 393.7160768763381, 0.7480333575647408)
# ('BLUE RUNNER', 200.08069128013557, 0.4240691062018552)
# ('HADDOCK', 302.92768271017724, 1.8003026792830874)
# ********** PERSON  1 **********
# ('RED DRUM', 514.5760074626236, 5.715137722394303)
# ('ATLANTIC SPADEFISH', 336.9297747658926, 2.4983546683186155)
# ('HADDOCK', 500.30068585494746, 1.1423759941175213)
# ********** PERSON  2 **********
# ('POLLOCK', 510.13193917551956, 2.629895256339892)
# ('PINFISH', 278.0237046643076, 0.26905239325826236)
# ('SCUP', 230.1655545203215, 1.258346845304475)
# ********** PERSON  3 **********
# ('ATLANTIC MACKEREL', 352.4452448275224, 1.0005716552466422)
# ('SCUP', 306.66936642033465, 0.1603038408928425)
# ('ATLANTIC MACKEREL', 341.6225749475292, 0.36925623732746343)
# ********** PERSON  4 **********
# ('WEAKFISH', 188.70551143174333, 1.384943281907968)
# ('YELLOWFIN TUNA', 1247.01217426106, 47.304259261376366)
# ('ATLANTIC CROAKER', 194.2953727229412, 0.5642148247249563)
# [(0, ('SAND SEATROUT', 393.7160768763381, 0.7480333575647408)),
#  (0, ('BLUE RUNNER', 200.08069128013557, 0.4240691062018552)),
#  (0, ('HADDOCK', 302.92768271017724, 1.8003026792830874)),
#  (1, ('RED DRUM', 514.5760074626236, 5.715137722394303)),
#  (1, ('ATLANTIC SPADEFISH', 336.9297747658926, 2.4983546683186155)),
#  (1, ('HADDOCK', 500.30068585494746, 1.1423759941175213)),
#  (2, ('POLLOCK', 510.13193917551956, 2.629895256339892)),
#  (2, ('PINFISH', 278.0237046643076, 0.26905239325826236)),
#  (2, ('SCUP', 230.1655545203215, 1.258346845304475)),
#  (3, ('ATLANTIC MACKEREL', 352.4452448275224, 1.0005716552466422)),
#  (3, ('SCUP', 306.66936642033465, 0.1603038408928425)),
#  (3, ('ATLANTIC MACKEREL', 341.6225749475292, 0.36925623732746343)),
#  (4, ('WEAKFISH', 188.70551143174333, 1.384943281907968)),
#  (4, ('YELLOWFIN TUNA', 1247.01217426106, 47.304259261376366)),
#  (4, ('ATLANTIC CROAKER', 194.2953727229412, 0.5642148247249563))]
